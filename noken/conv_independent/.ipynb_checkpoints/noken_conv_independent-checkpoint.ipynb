# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from torchvision.datasets import CIFAR10
import numpy as np
import matplotlib.pyplot as plt
import json
from datetime import datetime, timedelta
import os
from PIL import Image
if torch.cuda.is_available():
    print(torch.cuda.device_count())
device = torch.device("cuda:2")
print(device)
# Out:
# 3
# cuda:2

# %%
import glob
import re
import json
from pathlib import Path
np.random.seed(1)
torch.manual_seed(1)
torch.cuda.manual_seed(1)

# %%
history = 1
batchsize = 100
testsize = 10
epochs = 500
allsensors = ('sensor1', 'sensor2', 'sensor3', 'sensor5', 'sensor6')
fpath = '/proj/NARO/sonoda/noken/noken_0_50_selected'

# %%
alldata = {}
def sensdata(name):
    jso = open("../sonoda/{}/all.json".format(name))
    jsl = json.load(jso)
    alldata[name] = jsl
for sname in allsensors:
    sensdata(sname)

# %%
files = glob.glob(fpath+'/*.jpg')
sdata = []
fdata = []
tdata = []
counter = 0

for file in files:
    reres = re.findall('/proj/NARO/sonoda/noken/noken_0_50_selected/data_(20\d\d)(\d\d)(\d\d)_(\d\d)(\d\d)(\d\d).jpg', file)

    (year, month, day, hour, minute, sec) = reres[0]
    dt_date = datetime(int(year), int(month), int(day), int(hour), int(minute), int(sec))
    dt_epoch = int(dt_date.timestamp()/60)*60
    dt_adj = datetime.fromtimestamp(dt_epoch)
    dt_prev = dt_adj
    time_adj = dt_adj.strftime('%Y-%m-%d-%H-%M')
    time_prev = time_adj
    dt_source = dt_adj + timedelta(minutes = history -1)
    time_source = dt_source.strftime('%Y-%m-%d-%H-%M')
    sensd = []
    histerr = 0
    for sname in allsensors:
        if alldata[sname].get(time_source):
            print('time_source', time_source)
            print(sname + 'の分データ', alldata[sname].get(time_source))
            sensd.append(alldata[sname][time_source]['Temperature'])
        else:
            print('no_data')
            histerr = 1
            break
    if histerr:
        continue
    if not histerr:
        counter = counter + 1
        sdata.append(sensd)
        tdata.append(time_adj)
        fdata.append(file)
print(counter)
# Out:
# time_source 2022-01-10-17-19
# sensor1の分データ {'Temperature': 11.18, 'Humidity': 86.921875, 'Pressure': 1019.2823682001983, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-10-17-19
# sensor2の分データ {'Temperature': 11.8, 'Humidity': 83.171875, 'Pressure': 1019.1773861295491, 'UV': 0.0, 'AmbientLight': 86.20689655172413}
# time_source 2022-01-10-17-19
# sensor3の分データ {'Temperature': 11.1, 'Humidity': 85.25, 'Pressure': 1019.2036316472114, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-10-17-19
# sensor5の分データ {'Temperature': 12.24, 'Humidity': 85.140625, 'Pressure': 1019.2823682001983, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-10-17-19
# sensor6の分データ {'Temperature': 11.28, 'Humidity': 84.046875, 'Pressure': 1019.2823682001983, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# time_source 2022-01-12-07-32
# sensor1の分データ {'Temperature': 15.9, 'Humidity': 86.078125, 'Pressure': 1001.3698023956664, 'UV': 0.8505154639175256, 'AmbientLight': 2004.310344827586}
# time_source 2022-01-12-07-32
# sensor2の分データ {'Temperature': 16.18, 'Humidity': 79.203125, 'Pressure': 1001.6847486076142, 'UV': 0.5927835051546391, 'AmbientLight': 2349.137931034483}
# no_data
# no_data
# time_source 2022-01-12-07-01
# sensor1の分データ {'Temperature': 10.26, 'Humidity': 92.140625, 'Pressure': 1001.0942244602121, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-12-07-01
# sensor2の分データ {'Temperature': 12.54, 'Humidity': 84.8125, 'Pressure': 1001.0154879072252, 'UV': 0.02577319587628866, 'AmbientLight': 64.6551724137931}
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-02-03
# sensor1の分データ {'Temperature': 10.88, 'Humidity': 96.140625, 'Pressure': 998.115358205539, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-12-02-03
# sensor2の分データ {'Temperature': 12.6, 'Humidity': 89.46875, 'Pressure': 998.1022354467078, 'UV': 0.5412371134020618, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# time_source 2022-01-12-06-07
# sensor1の分データ {'Temperature': 9.04, 'Humidity': 90.875, 'Pressure': 1000.5561913481346, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2022-01-12-06-07
# sensor2の分データ {'Temperature': 10.5, 'Humidity': 84.5625, 'Pressure': 1000.5430685893034, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-15-49
# sensor1の分データ {'Temperature': 13.88, 'Humidity': 57.640625, 'Pressure': 996.789959563592, 'UV': 0.3092783505154639, 'AmbientLight': 668.103448275862}
# time_source 2022-01-13-15-49
# sensor2の分データ {'Temperature': 14.54, 'Humidity': 50.46875, 'Pressure': 996.6849774929427, 'UV': 0.1804123711340206, 'AmbientLight': 948.2758620689655}
# time_source 2022-01-13-15-49
# sensor3の分データ {'Temperature': 13.04, 'Humidity': 57.984375, 'Pressure': 996.789959563592, 'UV': 0.20618556701030927, 'AmbientLight': 581.8965517241379}
# time_source 2022-01-13-15-49
# sensor5の分データ {'Temperature': 14.58, 'Humidity': 55.859375, 'Pressure': 996.7505912870985, 'UV': 0.20618556701030927, 'AmbientLight': 668.103448275862}
# time_source 2022-01-13-15-49
# sensor6の分データ {'Temperature': 14.16, 'Humidity': 52.546875, 'Pressure': 996.789959563592, 'UV': 0.33505154639175255, 'AmbientLight': 1314.655172413793}
# time_source 2022-01-10-12-36
# sensor1の分データ {'Temperature': 19.5, 'Humidity': 73.484375, 'Pressure': 1017.8388647287709, 'UV': 0.7216494845360824, 'AmbientLight': 1443.9655172413793}
# time_source 2022-01-10-12-36
# sensor2の分データ {'Temperature': 21.14, 'Humidity': 67.578125, 'Pressure': 1017.8913557640955, 'UV': 0.7731958762886597, 'AmbientLight': 2693.965517241379}
# time_source 2022-01-10-12-36
# sensor3の分データ {'Temperature': 18.72, 'Humidity': 71.625, 'Pressure': 1017.9832150759137, 'UV': 0.6185567010309277, 'AmbientLight': 1594.8275862068965}
# time_source 2022-01-10-12-36
# sensor5の分データ {'Temperature': 19.96, 'Humidity': 68.546875, 'Pressure': 1017.8519874876021, 'UV': 0.747422680412371, 'AmbientLight': 2112.0689655172414}
# time_source 2022-01-10-12-36
# sensor6の分データ {'Temperature': 20.2, 'Humidity': 66.09375, 'Pressure': 1017.8913557640955, 'UV': 0.747422680412371, 'AmbientLight': 2672.413793103448}
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-09-15-19
# sensor1の分データ {'Temperature': 18.2, 'Humidity': 47.890625, 'Pressure': 1014.9256122682536, 'UV': 0.747422680412371, 'AmbientLight': 1422.4137931034481}
# time_source 2022-01-09-15-19
# sensor2の分データ {'Temperature': 22.76, 'Humidity': 39.390625, 'Pressure': 1014.8206301976044, 'UV': 0.9278350515463917, 'AmbientLight': 3469.8275862068963}
# time_source 2022-01-09-15-19
# sensor3の分データ {'Temperature': 17.14, 'Humidity': 48.84375, 'Pressure': 1014.9256122682536, 'UV': 0.33505154639175255, 'AmbientLight': 1099.1379310344826}
# time_source 2022-01-09-15-19
# sensor5の分データ {'Temperature': 19.22, 'Humidity': 45.53125, 'Pressure': 1014.8862439917601, 'UV': 0.5412371134020618, 'AmbientLight': 1831.8965517241377}
# time_source 2022-01-09-15-19
# sensor6の分データ {'Temperature': 19.24, 'Humidity': 42.46875, 'Pressure': 1014.8862439917601, 'UV': 0.5412371134020618, 'AmbientLight': 2758.620689655172}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-01-57
# sensor1の分データ {'Temperature': 9.72, 'Humidity': 96.453125, 'Pressure': 998.2334630350194, 'UV': 0.02577319587628866, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-12-01-57
# sensor2の分データ {'Temperature': 11.64, 'Humidity': 90.65625, 'Pressure': 998.1022354467078, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# time_source 2022-01-13-02-05
# sensor1の分データ {'Temperature': 10.14, 'Humidity': 77.4375, 'Pressure': 1005.3197528038453, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-13-02-05
# sensor2の分データ {'Temperature': 11.68, 'Humidity': 72.640625, 'Pressure': 1005.2410162508584, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-00-11
# sensor1の分データ {'Temperature': 10.84, 'Humidity': 98.5, 'Pressure': 997.1836423285267, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-12-00-11
# sensor2の分データ {'Temperature': 12.56, 'Humidity': 92.28125, 'Pressure': 997.118028534371, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# time_source 2022-01-11-22-56
# sensor1の分データ {'Temperature': 10.74, 'Humidity': 100.265625, 'Pressure': 996.7112230106051, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-11-22-56
# sensor2の分データ {'Temperature': 12.1, 'Humidity': 95.34375, 'Pressure': 996.6718547341115, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# time_source 2021-12-29-16-18
# sensor1の分データ {'Temperature': 12.04, 'Humidity': 71.203125, 'Pressure': 1016.7103074692913, 'UV': 0.02577319587628866, 'AmbientLight': 64.6551724137931}
# time_source 2021-12-29-16-18
# sensor2の分データ {'Temperature': 12.16, 'Humidity': 67.421875, 'Pressure': 1016.6578164339666, 'UV': 0.0, 'AmbientLight': 107.75862068965516}
# time_source 2021-12-29-16-18
# sensor3の分データ {'Temperature': 11.66, 'Humidity': 70.84375, 'Pressure': 1016.7234302281224, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2021-12-29-16-18
# sensor5の分データ {'Temperature': 13.08, 'Humidity': 69.84375, 'Pressure': 1016.7234302281224, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2021-12-29-16-18
# sensor6の分データ {'Temperature': 12.04, 'Humidity': 68.953125, 'Pressure': 1016.7103074692913, 'UV': 0.0, 'AmbientLight': 64.6551724137931}
# time_source 2021-12-29-14-39
# sensor1の分データ {'Temperature': 16.36, 'Humidity': 58.703125, 'Pressure': 1017.5632867933166, 'UV': 0.28350515463917525, 'AmbientLight': 732.7586206896551}
# time_source 2021-12-29-14-39
# sensor2の分データ {'Temperature': 17.0, 'Humidity': 54.5, 'Pressure': 1017.5107957579919, 'UV': 0.23195876288659792, 'AmbientLight': 991.3793103448276}
# time_source 2021-12-29-14-39
# sensor3の分データ {'Temperature': 15.6, 'Humidity': 59.5625, 'Pressure': 1017.6289005874723, 'UV': 0.1804123711340206, 'AmbientLight': 581.8965517241379}
# time_source 2021-12-29-14-39
# sensor5の分データ {'Temperature': 17.06, 'Humidity': 56.875, 'Pressure': 1017.5370412756542, 'UV': 0.25773195876288657, 'AmbientLight': 775.8620689655172}
# time_source 2021-12-29-14-39
# sensor6の分データ {'Temperature': 17.18, 'Humidity': 52.671875, 'Pressure': 1017.5370412756542, 'UV': 0.1804123711340206, 'AmbientLight': 969.8275862068965}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-02-10-52
# sensor1の分データ {'Temperature': 14.46, 'Humidity': 76.140625, 'Pressure': 1023.0092317082475, 'UV': 0.5154639175257731, 'AmbientLight': 1314.655172413793}
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-10-04-19
# sensor1の分データ {'Temperature': 9.46, 'Humidity': 83.4375, 'Pressure': 1017.3795681696803, 'UV': 0.02577319587628866, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-10-04-19
# sensor2の分データ {'Temperature': 10.44, 'Humidity': 79.71875, 'Pressure': 1017.274586099031, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-10-04-19
# sensor3の分データ {'Temperature': 9.22, 'Humidity': 80.84375, 'Pressure': 1017.3664454108491, 'UV': 0.10309278350515463, 'AmbientLight': 0.0}
# time_source 2022-01-10-04-19
# sensor5の分データ {'Temperature': 10.68, 'Humidity': 80.25, 'Pressure': 1017.4451819638361, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-10-04-19
# sensor6の分データ {'Temperature': 10.38, 'Humidity': 79.25, 'Pressure': 1017.353322652018, 'UV': 0.05154639175257732, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-02-13
# sensor1の分データ {'Temperature': 9.48, 'Humidity': 95.5, 'Pressure': 998.4040588998246, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-12-02-13
# sensor2の分データ {'Temperature': 10.76, 'Humidity': 89.421875, 'Pressure': 998.272831311513, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-14-40
# sensor1の分データ {'Temperature': 19.6, 'Humidity': 53.015625, 'Pressure': 996.9868009460594, 'UV': 0.9278350515463917, 'AmbientLight': 2133.620689655172}
# time_source 2022-01-13-14-40
# sensor2の分データ {'Temperature': 25.62, 'Humidity': 42.9375, 'Pressure': 996.9736781872282, 'UV': 1.0567010309278349, 'AmbientLight': 3685.3448275862065}
# time_source 2022-01-13-14-40
# sensor3の分データ {'Temperature': 18.76, 'Humidity': 51.234375, 'Pressure': 996.9736781872282, 'UV': 0.6701030927835051, 'AmbientLight': 1767.2413793103447}
# time_source 2022-01-13-14-40
# sensor5の分データ {'Temperature': 20.58, 'Humidity': 48.6875, 'Pressure': 996.7505912870985, 'UV': 0.5927835051546391, 'AmbientLight': 1939.655172413793}
# time_source 2022-01-13-14-40
# sensor6の分データ {'Temperature': 25.0, 'Humidity': 42.625, 'Pressure': 996.9868009460594, 'UV': 0.902061855670103, 'AmbientLight': 3491.3793103448274}
# no_data
# no_data
# time_source 2021-12-29-19-53
# sensor1の分データ {'Temperature': 9.52, 'Humidity': 76.78125, 'Pressure': 1015.3324177920196, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2021-12-29-19-53
# sensor2の分データ {'Temperature': 10.62, 'Humidity': 72.34375, 'Pressure': 1015.293049515526, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-00-18
# sensor1の分データ {'Temperature': 10.58, 'Humidity': 78.578125, 'Pressure': 1005.9758907454033, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-13-00-18
# sensor2の分データ {'Temperature': 12.08, 'Humidity': 73.625, 'Pressure': 1005.9758907454033, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-04-58
# sensor1の分データ {'Temperature': 10.18, 'Humidity': 92.515625, 'Pressure': 1000.2412451361868, 'UV': 0.02577319587628866, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-12-04-58
# sensor2の分データ {'Temperature': 11.8, 'Humidity': 85.96875, 'Pressure': 1000.1625085831998, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-14-45
# sensor1の分データ {'Temperature': 19.46, 'Humidity': 53.21875, 'Pressure': 996.8686961165789, 'UV': 0.6958762886597938, 'AmbientLight': 1637.9310344827584}
# time_source 2022-01-13-14-45
# sensor2の分データ {'Temperature': 22.94, 'Humidity': 44.171875, 'Pressure': 996.8293278400854, 'UV': 0.747422680412371, 'AmbientLight': 3168.103448275862}
# time_source 2022-01-13-14-45
# sensor3の分データ {'Temperature': 17.86, 'Humidity': 51.78125, 'Pressure': 996.9080643930724, 'UV': 0.38659793814432986, 'AmbientLight': 1228.4482758620688}
# time_source 2022-01-13-14-45
# sensor5の分データ {'Temperature': 19.54, 'Humidity': 48.6875, 'Pressure': 996.6718547341115, 'UV': 0.48969072164948446, 'AmbientLight': 1810.3448275862067}
# time_source 2022-01-13-14-45
# sensor6の分データ {'Temperature': 23.58, 'Humidity': 42.375, 'Pressure': 996.8162050812543, 'UV': 0.747422680412371, 'AmbientLight': 3189.655172413793}
# time_source 2022-01-12-00-00
# sensor1の分データ {'Temperature': 9.56, 'Humidity': 98.078125, 'Pressure': 997.0130464637217, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-12-00-00
# sensor2の分データ {'Temperature': 10.8, 'Humidity': 92.1875, 'Pressure': 997.0392919813839, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-06-29
# sensor1の分データ {'Temperature': 10.18, 'Humidity': 92.15625, 'Pressure': 1000.7792782482643, 'UV': 0.15463917525773194, 'AmbientLight': 0.0}
# time_source 2022-01-12-06-29
# sensor2の分データ {'Temperature': 12.34, 'Humidity': 84.765625, 'Pressure': 1000.6611734187838, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-15-17
# sensor1の分データ {'Temperature': 18.38, 'Humidity': 53.78125, 'Pressure': 996.7374685282673, 'UV': 0.5927835051546391, 'AmbientLight': 1465.5172413793102}
# time_source 2022-01-13-15-17
# sensor2の分データ {'Temperature': 25.28, 'Humidity': 43.921875, 'Pressure': 996.7374685282673, 'UV': 1.3659793814432988, 'AmbientLight': 4827.586206896552}
# time_source 2022-01-13-15-17
# sensor3の分データ {'Temperature': 16.88, 'Humidity': 54.4375, 'Pressure': 996.789959563592, 'UV': 0.3092783505154639, 'AmbientLight': 883.6206896551723}
# time_source 2022-01-13-15-17
# sensor5の分データ {'Temperature': 19.4, 'Humidity': 51.53125, 'Pressure': 996.6062409399558, 'UV': 0.5154639175257731, 'AmbientLight': 1702.5862068965516}
# time_source 2022-01-13-15-17
# sensor6の分データ {'Temperature': 19.56, 'Humidity': 47.296875, 'Pressure': 996.7243457694361, 'UV': 0.5412371134020618, 'AmbientLight': 2586.2068965517237}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-02-08-20
# sensor1の分データ {'Temperature': 10.82, 'Humidity': 70.71875, 'Pressure': 1024.373998626688, 'UV': 0.25773195876288657, 'AmbientLight': 538.7931034482758}
# time_source 2022-01-02-08-20
# sensor2の分データ {'Temperature': 12.34, 'Humidity': 66.0625, 'Pressure': 1024.3477531090257, 'UV': 0.28350515463917525, 'AmbientLight': 948.2758620689655}
# time_source 2022-01-02-08-20
# sensor3の分データ {'Temperature': 11.12, 'Humidity': 69.234375, 'Pressure': 1024.4658579385061, 'UV': 0.1804123711340206, 'AmbientLight': 366.37931034482756}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2021-12-17-17-11
# sensor1の分データ {'Temperature': 11.9, 'Humidity': 93.25, 'Pressure': 994.2047760738536, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2021-12-17-17-11
# sensor2の分データ {'Temperature': 11.94, 'Humidity': 91.59375, 'Pressure': 994.152285038529, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2021-12-17-17-11
# sensor3の分データ {'Temperature': 11.62, 'Humidity': 91.859375, 'Pressure': 994.2572671091783, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2021-12-17-17-11
# sensor5の分データ {'Temperature': 12.4, 'Humidity': 93.359375, 'Pressure': 994.231021591516, 'UV': 0.05154639175257732, 'AmbientLight': 0.0}
# time_source 2021-12-17-17-11
# sensor6の分データ {'Temperature': 11.58, 'Humidity': 91.84375, 'Pressure': 994.2572671091783, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-01-20
# sensor1の分データ {'Temperature': 10.24, 'Humidity': 98.265625, 'Pressure': 997.8004119935912, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2022-01-12-01-20
# sensor2の分データ {'Temperature': 12.06, 'Humidity': 91.78125, 'Pressure': 997.7085526817731, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# time_source 2022-01-13-12-22
# sensor1の分データ {'Temperature': 19.64, 'Humidity': 49.296875, 'Pressure': 999.3357747768368, 'UV': 0.9793814432989689, 'AmbientLight': 2370.6896551724135}
# time_source 2022-01-13-12-22
# sensor2の分データ {'Temperature': 23.56, 'Humidity': 41.09375, 'Pressure': 999.2176699473564, 'UV': 1.0567010309278349, 'AmbientLight': 3706.8965517241377}
# time_source 2022-01-13-12-22
# sensor3の分データ {'Temperature': 17.5, 'Humidity': 47.265625, 'Pressure': 999.3357747768368, 'UV': 0.5670103092783505, 'AmbientLight': 1681.0344827586205}
# time_source 2022-01-13-12-22
# sensor5の分データ {'Temperature': 22.16, 'Humidity': 43.734375, 'Pressure': 999.1520561532005, 'UV': 0.9278350515463917, 'AmbientLight': 3599.1379310344823}
# time_source 2022-01-13-12-22
# sensor6の分データ {'Temperature': 23.2, 'Humidity': 41.78125, 'Pressure': 999.3357747768368, 'UV': 0.902061855670103, 'AmbientLight': 4202.586206896552}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2021-12-30-00-56
# sensor1の分データ {'Temperature': 10.3, 'Humidity': 75.15625, 'Pressure': 1011.2643625543602, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2021-12-30-00-56
# sensor2の分データ {'Temperature': 11.64, 'Humidity': 70.15625, 'Pressure': 1011.1856260013733, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2021-12-30-00-56
# sensor3の分データ {'Temperature': 10.1, 'Humidity': 74.359375, 'Pressure': 1011.2512397955292, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2021-12-30-00-56
# sensor5の分データ {'Temperature': 10.64, 'Humidity': 73.5, 'Pressure': 1011.2774853131914, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2021-12-30-00-56
# sensor6の分データ {'Temperature': 10.82, 'Humidity': 71.421875, 'Pressure': 1011.3037308308537, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# no_data
# no_data
# time_source 2022-01-09-23-47
# sensor1の分データ {'Temperature': 11.18, 'Humidity': 84.234375, 'Pressure': 1017.1827267872129, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-09-23-47
# sensor2の分データ {'Temperature': 12.34, 'Humidity': 80.203125, 'Pressure': 1017.1302357518883, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-09-23-47
# sensor3の分データ {'Temperature': 10.88, 'Humidity': 81.703125, 'Pressure': 1017.103990234226, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-09-23-47
# sensor5の分データ {'Temperature': 12.2, 'Humidity': 82.0, 'Pressure': 1017.1696040283817, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-09-23-47
# sensor6の分データ {'Temperature': 11.74, 'Humidity': 81.046875, 'Pressure': 1017.2089723048753, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-08-02-40
# sensor1の分データ {'Temperature': 8.28, 'Humidity': 73.328125, 'Pressure': 1022.5368123903257, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-08-02-40
# sensor2の分データ {'Temperature': 9.96, 'Humidity': 67.890625, 'Pressure': 1022.4449530785076, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-08-02-40
# sensor3の分データ {'Temperature': 8.24, 'Humidity': 71.921875, 'Pressure': 1022.628671702144, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-08-02-40
# sensor5の分データ {'Temperature': 9.82, 'Humidity': 69.703125, 'Pressure': 1022.5499351491569, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-08-02-40
# sensor6の分データ {'Temperature': 9.74, 'Humidity': 68.96875, 'Pressure': 1022.5368123903257, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-13-16-58
# sensor1の分データ {'Temperature': 11.16, 'Humidity': 75.9375, 'Pressure': 997.7610437170978, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# time_source 2022-01-13-01-38
# sensor1の分データ {'Temperature': 9.3, 'Humidity': 78.03125, 'Pressure': 1005.2410162508584, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-13-01-38
# sensor2の分データ {'Temperature': 10.64, 'Humidity': 72.96875, 'Pressure': 1005.1754024567025, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-16-05
# sensor1の分データ {'Temperature': 13.46, 'Humidity': 62.75, 'Pressure': 996.8686961165789, 'UV': 0.07731958762886597, 'AmbientLight': 172.41379310344826}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-13-26
# sensor1の分データ {'Temperature': 18.04, 'Humidity': 50.9375, 'Pressure': 997.9841306172274, 'UV': 1.2628865979381443, 'AmbientLight': 1142.2413793103447}
# time_source 2022-01-13-13-26
# sensor2の分データ {'Temperature': 20.16, 'Humidity': 43.296875, 'Pressure': 997.944762340734, 'UV': 1.0309278350515463, 'AmbientLight': 3836.2068965517237}
# time_source 2022-01-13-13-26
# sensor3の分データ {'Temperature': 16.82, 'Humidity': 49.15625, 'Pressure': 998.0234988937209, 'UV': 0.6958762886597938, 'AmbientLight': 2047.4137931034481}
# time_source 2022-01-13-13-26
# sensor5の分データ {'Temperature': 19.78, 'Humidity': 44.09375, 'Pressure': 997.8791485465781, 'UV': 0.7216494845360824, 'AmbientLight': 2607.758620689655}
# time_source 2022-01-13-13-26
# sensor6の分データ {'Temperature': 20.7, 'Humidity': 41.640625, 'Pressure': 997.9578850995651, 'UV': 0.902061855670103, 'AmbientLight': 4267.241379310344}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-00-45
# sensor1の分データ {'Temperature': 9.6, 'Humidity': 76.921875, 'Pressure': 1005.8577859159228, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-13-00-45
# sensor2の分データ {'Temperature': 10.64, 'Humidity': 72.21875, 'Pressure': 1005.7396810864424, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-15-33
# sensor1の分データ {'Temperature': 16.24, 'Humidity': 54.21875, 'Pressure': 996.6981002517739, 'UV': 0.12886597938144329, 'AmbientLight': 344.8275862068965}
# time_source 2022-01-13-15-33
# sensor2の分データ {'Temperature': 19.4, 'Humidity': 44.453125, 'Pressure': 996.5931181811246, 'UV': 0.15463917525773194, 'AmbientLight': 689.655172413793}
# time_source 2022-01-13-15-33
# sensor3の分データ {'Temperature': 15.12, 'Humidity': 54.046875, 'Pressure': 996.7374685282673, 'UV': 0.07731958762886597, 'AmbientLight': 258.6206896551724}
# time_source 2022-01-13-15-33
# sensor5の分データ {'Temperature': 16.9, 'Humidity': 51.359375, 'Pressure': 996.6456092164492, 'UV': 0.10309278350515463, 'AmbientLight': 431.03448275862064}
# time_source 2022-01-13-15-33
# sensor6の分データ {'Temperature': 17.18, 'Humidity': 48.546875, 'Pressure': 996.6981002517739, 'UV': 0.10309278350515463, 'AmbientLight': 689.655172413793}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-01-43
# sensor1の分データ {'Temperature': 10.32, 'Humidity': 79.4375, 'Pressure': 1005.293507286183, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-13-01-43
# sensor2の分データ {'Temperature': 12.46, 'Humidity': 74.03125, 'Pressure': 1005.2672617685206, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# time_source 2022-01-01-10-58
# sensor1の分データ {'Temperature': 22.78, 'Humidity': 54.09375, 'Pressure': 1018.0357061112383, 'UV': 1.0567010309278349, 'AmbientLight': 2887.9310344827586}
# time_source 2022-01-01-10-58
# sensor2の分データ {'Temperature': 26.44, 'Humidity': 47.15625, 'Pressure': 1018.0619516289006, 'UV': 0.7989690721649484, 'AmbientLight': 3491.3793103448274}
# time_source 2022-01-01-10-58
# sensor3の分データ {'Temperature': 25.62, 'Humidity': 49.65625, 'Pressure': 1018.2719157701991, 'UV': 0.8247422680412371, 'AmbientLight': 2025.862068965517}
# time_source 2022-01-01-10-58
# sensor5の分データ {'Temperature': 24.86, 'Humidity': 50.71875, 'Pressure': 1018.0225833524071, 'UV': 0.7989690721649484, 'AmbientLight': 3340.5172413793102}
# time_source 2022-01-01-10-58
# sensor6の分データ {'Temperature': 25.26, 'Humidity': 50.34375, 'Pressure': 1018.2194247348745, 'UV': 0.8247422680412371, 'AmbientLight': 3836.2068965517237}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-10-23-31
# sensor1の分データ {'Temperature': 10.8, 'Humidity': 92.46875, 'Pressure': 1018.4687571526665, 'UV': 0.02577319587628866, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-10-23-31
# sensor2の分データ {'Temperature': 11.76, 'Humidity': 88.65625, 'Pressure': 1018.4162661173419, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-10-23-31
# sensor3の分データ {'Temperature': 10.62, 'Humidity': 89.078125, 'Pressure': 1018.4950026703289, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-10-23-31
# sensor5の分データ {'Temperature': 11.9, 'Humidity': 89.78125, 'Pressure': 1018.5343709468223, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-10-23-31
# sensor6の分データ {'Temperature': 11.36, 'Humidity': 88.65625, 'Pressure': 1018.5212481879912, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# time_source 2022-01-13-12-43
# sensor1の分データ {'Temperature': 19.44, 'Humidity': 51.0625, 'Pressure': 998.771496147097, 'UV': 0.9536082474226804, 'AmbientLight': 2306.0344827586205}
# time_source 2022-01-13-12-43
# sensor2の分データ {'Temperature': 21.58, 'Humidity': 42.53125, 'Pressure': 998.69275959411, 'UV': 0.7731958762886597, 'AmbientLight': 3448.275862068965}
# time_source 2022-01-13-12-43
# sensor3の分データ {'Temperature': 17.98, 'Humidity': 48.78125, 'Pressure': 998.8108644235905, 'UV': 0.6185567010309277, 'AmbientLight': 1961.206896551724}
# time_source 2022-01-13-12-43
# sensor5の分データ {'Temperature': 22.16, 'Humidity': 44.46875, 'Pressure': 998.5746547646296, 'UV': 0.8505154639175256, 'AmbientLight': 3340.5172413793102}
# time_source 2022-01-13-12-43
# sensor6の分データ {'Temperature': 23.0, 'Humidity': 42.609375, 'Pressure': 998.7846189059281, 'UV': 0.902061855670103, 'AmbientLight': 4331.896551724138}
# no_data
# no_data
# time_source 2022-01-13-17-36
# sensor1の分データ {'Temperature': 11.64, 'Humidity': 79.859375, 'Pressure': 998.4040588998246, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-13-17-36
# sensor2の分データ {'Temperature': 12.26, 'Humidity': 76.0, 'Pressure': 998.3384451056687, 'UV': 0.07731958762886597, 'AmbientLight': 237.06896551724137}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-11-22-30
# sensor1の分データ {'Temperature': 11.42, 'Humidity': 101.359375, 'Pressure': 996.6456092164492, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-11-22-30
# sensor2の分データ {'Temperature': 12.8, 'Humidity': 96.296875, 'Pressure': 996.6718547341115, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-06-04
# sensor1の分データ {'Temperature': 10.74, 'Humidity': 80.765625, 'Pressure': 1004.388036926833, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-13-06-04
# sensor2の分データ {'Temperature': 11.96, 'Humidity': 75.390625, 'Pressure': 1004.3617914091707, 'UV': 0.05154639175257732, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-08-58
# sensor1の分データ {'Temperature': 24.2, 'Humidity': 69.546875, 'Pressure': 1002.157167925536, 'UV': 1.3917525773195876, 'AmbientLight': 3448.275862068965}
# time_source 2022-01-12-08-58
# sensor2の分データ {'Temperature': 20.1, 'Humidity': 74.640625, 'Pressure': 1002.2752727550164, 'UV': 0.6701030927835051, 'AmbientLight': 3103.448275862069}
# no_data
# no_data
# time_source 2022-01-11-22-46
# sensor1の分データ {'Temperature': 10.14, 'Humidity': 101.40625, 'Pressure': 996.789959563592, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-11-22-46
# sensor2の分データ {'Temperature': 11.28, 'Humidity': 97.046875, 'Pressure': 996.6849774929427, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# time_source 2022-01-13-14-19
# sensor1の分データ {'Temperature': 17.66, 'Humidity': 50.859375, 'Pressure': 997.0524147402151, 'UV': 0.7216494845360824, 'AmbientLight': 1594.8275862068965}
# time_source 2022-01-13-14-19
# sensor2の分データ {'Temperature': 20.92, 'Humidity': 42.625, 'Pressure': 996.9999237048905, 'UV': 0.6701030927835051, 'AmbientLight': 2672.413793103448}
# time_source 2022-01-13-14-19
# sensor3の分データ {'Temperature': 16.08, 'Humidity': 49.640625, 'Pressure': 997.0655374990463, 'UV': 0.43814432989690716, 'AmbientLight': 1185.3448275862067}
# time_source 2022-01-13-14-19
# sensor5の分データ {'Temperature': 17.34, 'Humidity': 47.890625, 'Pressure': 996.9211871519036, 'UV': 0.43814432989690716, 'AmbientLight': 1508.6206896551723}
# time_source 2022-01-13-14-19
# sensor6の分データ {'Temperature': 22.04, 'Humidity': 41.625, 'Pressure': 996.9868009460594, 'UV': 0.6958762886597938, 'AmbientLight': 2801.7241379310344}
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-00-13
# sensor1の分データ {'Temperature': 9.5, 'Humidity': 76.90625, 'Pressure': 1006.0546272983902, 'UV': 0.05154639175257732, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-13-00-13
# sensor2の分データ {'Temperature': 10.62, 'Humidity': 72.15625, 'Pressure': 1005.9758907454033, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# time_source 2022-01-12-09-56
# sensor1の分データ {'Temperature': 24.14, 'Humidity': 66.015625, 'Pressure': 1002.5377279316396, 'UV': 1.0051546391752577, 'AmbientLight': 2693.965517241379}
# time_source 2022-01-12-09-56
# sensor2の分データ {'Temperature': 26.9, 'Humidity': 63.453125, 'Pressure': 1002.5770962081331, 'UV': 0.9536082474226804, 'AmbientLight': 3900.8620689655168}
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-02-08
# sensor1の分データ {'Temperature': 10.02, 'Humidity': 94.9375, 'Pressure': 998.2334630350194, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-12-02-08
# sensor2の分データ {'Temperature': 11.52, 'Humidity': 88.796875, 'Pressure': 998.1809719996949, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-09-00
# sensor1の分データ {'Temperature': 22.38, 'Humidity': 67.34375, 'Pressure': 1003.4694438086518, 'UV': 1.4175257731958761, 'AmbientLight': 3362.068965517241}
# time_source 2022-01-13-09-00
# sensor2の分データ {'Temperature': 19.34, 'Humidity': 71.171875, 'Pressure': 1003.640039673457, 'UV': 0.6443298969072164, 'AmbientLight': 3060.3448275862065}
# time_source 2022-01-13-09-00
# sensor3の分データ {'Temperature': 16.92, 'Humidity': 74.96875, 'Pressure': 1003.6531624322881, 'UV': 0.5927835051546391, 'AmbientLight': 1616.3793103448274}
# time_source 2022-01-13-09-00
# sensor5の分データ {'Temperature': 19.8, 'Humidity': 71.078125, 'Pressure': 1003.4169527733272, 'UV': 0.747422680412371, 'AmbientLight': 2823.275862068965}
# time_source 2022-01-13-09-00
# sensor6の分データ {'Temperature': 22.8, 'Humidity': 65.890625, 'Pressure': 1003.6269169146258, 'UV': 0.7216494845360824, 'AmbientLight': 3836.2068965517237}
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-06-20
# sensor1の分データ {'Temperature': 10.62, 'Humidity': 81.875, 'Pressure': 1004.4405279621576, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-13-06-20
# sensor2の分データ {'Temperature': 12.04, 'Humidity': 75.984375, 'Pressure': 1004.5061417563135, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-06-16-49
# sensor1の分データ {'Temperature': 9.34, 'Humidity': 79.4375, 'Pressure': 1021.158922713054, 'UV': 0.05154639175257732, 'AmbientLight': 64.6551724137931}
# time_source 2022-01-06-16-49
# sensor2の分データ {'Temperature': 10.56, 'Humidity': 75.703125, 'Pressure': 1021.0933089188983, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-06-16-49
# sensor3の分データ {'Temperature': 9.24, 'Humidity': 78.921875, 'Pressure': 1021.145799954223, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-06-16-49
# sensor5の分データ {'Temperature': 10.6, 'Humidity': 76.734375, 'Pressure': 1021.1982909895476, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-06-16-49
# sensor6の分データ {'Temperature': 10.32, 'Humidity': 76.40625, 'Pressure': 1021.1064316777295, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-13-52
# sensor1の分データ {'Temperature': 18.16, 'Humidity': 50.875, 'Pressure': 997.5510795757992, 'UV': 0.8762886597938143, 'AmbientLight': 1939.655172413793}
# time_source 2022-01-13-13-52
# sensor2の分データ {'Temperature': 20.38, 'Humidity': 44.28125, 'Pressure': 997.4723430228122, 'UV': 0.6958762886597938, 'AmbientLight': 3232.758620689655}
# time_source 2022-01-13-13-52
# sensor3の分データ {'Temperature': 17.68, 'Humidity': 49.484375, 'Pressure': 997.5773250934615, 'UV': 0.6185567010309277, 'AmbientLight': 1831.8965517241377}
# time_source 2022-01-13-13-52
# sensor5の分データ {'Temperature': 18.62, 'Humidity': 46.984375, 'Pressure': 997.3936064698253, 'UV': 0.5927835051546391, 'AmbientLight': 2025.862068965517}
# time_source 2022-01-13-13-52
# sensor6の分データ {'Temperature': 22.0, 'Humidity': 42.453125, 'Pressure': 997.4854657816434, 'UV': 0.8762886597938143, 'AmbientLight': 3900.8620689655168}
# no_data
# time_source 2022-01-13-16-42
# sensor1の分データ {'Temperature': 12.08, 'Humidity': 73.078125, 'Pressure': 997.4329747463188, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-03-12
# sensor1の分データ {'Temperature': 10.72, 'Humidity': 96.140625, 'Pressure': 999.2439154650187, 'UV': 0.05154639175257732, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-12-03-12
# sensor2の分データ {'Temperature': 12.66, 'Humidity': 89.34375, 'Pressure': 999.1783016708629, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-22-42
# sensor1の分データ {'Temperature': 10.48, 'Humidity': 76.96875, 'Pressure': 1006.0546272983902, 'UV': 0.05154639175257732, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-12-22-42
# sensor2の分データ {'Temperature': 11.74, 'Humidity': 72.1875, 'Pressure': 1006.0546272983902, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# no_data
# time_source 2022-01-13-09-47
# sensor1の分データ {'Temperature': 25.46, 'Humidity': 64.15625, 'Pressure': 1003.233234149691, 'UV': 1.1082474226804122, 'AmbientLight': 3038.793103448276}
# time_source 2022-01-13-09-47
# sensor2の分データ {'Temperature': 26.26, 'Humidity': 63.40625, 'Pressure': 1003.3382162203403, 'UV': 0.8505154639175256, 'AmbientLight': 3793.103448275862}
# time_source 2022-01-13-09-47
# sensor3の分データ {'Temperature': 25.9, 'Humidity': 65.078125, 'Pressure': 1003.482566567483, 'UV': 0.9536082474226804, 'AmbientLight': 3038.793103448276}
# time_source 2022-01-13-09-47
# sensor5の分データ {'Temperature': 26.72, 'Humidity': 61.890625, 'Pressure': 1003.0101472495613, 'UV': 1.0567010309278349, 'AmbientLight': 4288.793103448275}
# time_source 2022-01-13-09-47
# sensor6の分データ {'Temperature': 22.4, 'Humidity': 66.859375, 'Pressure': 1003.3644617380025, 'UV': 0.6443298969072164, 'AmbientLight': 3426.7241379310344}
# no_data
# time_source 2022-01-13-00-34
# sensor1の分データ {'Temperature': 10.28, 'Humidity': 78.71875, 'Pressure': 1005.9758907454033, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-13-00-34
# sensor2の分データ {'Temperature': 11.82, 'Humidity': 73.671875, 'Pressure': 1005.9102769512474, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-08-23-37
# sensor1の分データ {'Temperature': 9.14, 'Humidity': 74.859375, 'Pressure': 1018.7837033646143, 'UV': 0.05154639175257732, 'AmbientLight': 0.0}
# time_source 2022-01-08-23-37
# sensor2の分データ {'Temperature': 10.66, 'Humidity': 69.953125, 'Pressure': 1018.7049668116274, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-08-23-37
# sensor3の分データ {'Temperature': 8.8, 'Humidity': 72.90625, 'Pressure': 1018.7968261234455, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2022-01-08-23-37
# sensor5の分データ {'Temperature': 10.76, 'Humidity': 71.40625, 'Pressure': 1018.8230716411078, 'UV': 0.05154639175257732, 'AmbientLight': 0.0}
# time_source 2022-01-08-23-37
# sensor6の分データ {'Temperature': 10.62, 'Humidity': 70.9375, 'Pressure': 1018.836194399939, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# no_data
# no_data
# time_source 2022-01-12-02-19
# sensor1の分データ {'Temperature': 10.8, 'Humidity': 97.09375, 'Pressure': 998.4959182116427, 'UV': 0.3092783505154639, 'AmbientLight': 0.0}
# time_source 2022-01-12-02-19
# sensor2の分データ {'Temperature': 12.78, 'Humidity': 90.125, 'Pressure': 998.3909361409934, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# time_source 2022-01-12-06-45
# sensor1の分データ {'Temperature': 10.32, 'Humidity': 92.109375, 'Pressure': 1000.8055237659266, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-12-06-45
# sensor2の分データ {'Temperature': 12.44, 'Humidity': 84.609375, 'Pressure': 1000.7399099717708, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2021-12-17-17-17
# sensor1の分データ {'Temperature': 11.8, 'Humidity': 93.40625, 'Pressure': 994.2966353856718, 'UV': 0.05154639175257732, 'AmbientLight': 0.0}
# time_source 2021-12-17-17-17
# sensor2の分データ {'Temperature': 11.86, 'Humidity': 91.875, 'Pressure': 994.2703898680095, 'UV': 0.05154639175257732, 'AmbientLight': 0.0}
# time_source 2021-12-17-17-17
# sensor3の分データ {'Temperature': 11.54, 'Humidity': 92.078125, 'Pressure': 994.2966353856718, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2021-12-17-17-17
# sensor5の分データ {'Temperature': 12.34, 'Humidity': 93.5625, 'Pressure': 994.3491264209964, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2021-12-17-17-17
# sensor6の分データ {'Temperature': 11.5, 'Humidity': 92.140625, 'Pressure': 994.3097581445029, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-14-56
# sensor1の分データ {'Temperature': 18.72, 'Humidity': 52.234375, 'Pressure': 996.7637140459296, 'UV': 0.7989690721649484, 'AmbientLight': 1896.551724137931}
# time_source 2022-01-13-14-56
# sensor2の分データ {'Temperature': 20.54, 'Humidity': 45.234375, 'Pressure': 996.6718547341115, 'UV': 0.7216494845360824, 'AmbientLight': 3081.8965517241377}
# time_source 2022-01-13-14-56
# sensor3の分データ {'Temperature': 16.3, 'Humidity': 52.0, 'Pressure': 996.7374685282673, 'UV': 0.38659793814432986, 'AmbientLight': 1163.7931034482758}
# time_source 2022-01-13-14-56
# sensor5の分データ {'Temperature': 18.06, 'Humidity': 49.03125, 'Pressure': 996.632486457618, 'UV': 0.5154639175257731, 'AmbientLight': 1745.6896551724137}
# time_source 2022-01-13-14-56
# sensor6の分データ {'Temperature': 19.66, 'Humidity': 43.796875, 'Pressure': 996.7243457694361, 'UV': 0.6443298969072164, 'AmbientLight': 3038.793103448276}
# time_source 2022-01-06-18-08
# sensor1の分データ {'Temperature': 9.36, 'Humidity': 81.5, 'Pressure': 1021.0801861600671, 'UV': 0.07731958762886597, 'AmbientLight': 0.0}
# time_source 2022-01-06-18-08
# sensor2の分データ {'Temperature': 11.08, 'Humidity': 76.890625, 'Pressure': 1021.0145723659114, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-06-18-08
# sensor3の分データ {'Temperature': 9.16, 'Humidity': 80.09375, 'Pressure': 1021.1064316777295, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-06-18-08
# sensor5の分データ {'Temperature': 10.66, 'Humidity': 78.03125, 'Pressure': 1021.1195544365606, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-06-18-08
# sensor6の分データ {'Temperature': 10.4, 'Humidity': 77.015625, 'Pressure': 1021.1326771953918, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# time_source 2022-01-12-00-43
# sensor1の分データ {'Temperature': 10.28, 'Humidity': 99.046875, 'Pressure': 997.5510795757992, 'UV': 0.07731958762886597, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-12-00-43
# sensor2の分データ {'Temperature': 12.2, 'Humidity': 92.71875, 'Pressure': 997.5117112993057, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2021-12-30-11-20
# sensor1の分データ {'Temperature': 22.32, 'Humidity': 51.71875, 'Pressure': 1004.4405279621576, 'UV': 1.0309278350515463, 'AmbientLight': 2586.2068965517237}
# time_source 2021-12-30-11-20
# sensor2の分データ {'Temperature': 22.8, 'Humidity': 46.140625, 'Pressure': 1004.388036926833, 'UV': 0.6958762886597938, 'AmbientLight': 3275.8620689655168}
# time_source 2021-12-30-11-20
# sensor3の分データ {'Temperature': 22.0, 'Humidity': 49.328125, 'Pressure': 1004.5323872739757, 'UV': 0.6185567010309277, 'AmbientLight': 1659.4827586206895}
# time_source 2021-12-30-11-20
# sensor5の分データ {'Temperature': 23.84, 'Humidity': 49.03125, 'Pressure': 1004.3355458915083, 'UV': 0.902061855670103, 'AmbientLight': 3534.4827586206893}
# time_source 2021-12-30-11-20
# sensor6の分データ {'Temperature': 23.24, 'Humidity': 47.53125, 'Pressure': 1004.5323872739757, 'UV': 0.747422680412371, 'AmbientLight': 3534.4827586206893}
# time_source 2022-01-13-14-35
# sensor1の分データ {'Temperature': 18.24, 'Humidity': 52.4375, 'Pressure': 997.0130464637217, 'UV': 0.9793814432989689, 'AmbientLight': 2370.6896551724135}
# time_source 2022-01-13-14-35
# sensor2の分データ {'Temperature': 24.8, 'Humidity': 42.8125, 'Pressure': 997.0917830167086, 'UV': 1.4690721649484535, 'AmbientLight': 4849.137931034483}
# time_source 2022-01-13-14-35
# sensor3の分データ {'Temperature': 17.82, 'Humidity': 50.65625, 'Pressure': 997.0655374990463, 'UV': 0.7731958762886597, 'AmbientLight': 1874.9999999999998}
# time_source 2022-01-13-14-35
# sensor5の分データ {'Temperature': 18.98, 'Humidity': 48.828125, 'Pressure': 996.960555428397, 'UV': 0.7731958762886597, 'AmbientLight': 2370.6896551724135}
# time_source 2022-01-13-14-35
# sensor6の分データ {'Temperature': 23.68, 'Humidity': 42.40625, 'Pressure': 997.1049057755398, 'UV': 0.9793814432989689, 'AmbientLight': 4094.8275862068963}
# no_data
# no_data
# time_source 2022-01-13-00-50
# sensor1の分データ {'Temperature': 10.06, 'Humidity': 78.609375, 'Pressure': 1005.6478217746243, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-13-00-50
# sensor2の分データ {'Temperature': 11.52, 'Humidity': 73.625, 'Pressure': 1005.5690852216372, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# time_source 2022-01-06-08-32
# sensor1の分データ {'Temperature': 11.42, 'Humidity': 75.21875, 'Pressure': 1025.1744869153886, 'UV': 0.20618556701030927, 'AmbientLight': 517.2413793103448}
# time_source 2022-01-06-08-32
# sensor2の分データ {'Temperature': 12.1, 'Humidity': 71.78125, 'Pressure': 1025.1482413977265, 'UV': 0.33505154639175255, 'AmbientLight': 926.7241379310344}
# time_source 2022-01-06-08-32
# sensor3の分データ {'Temperature': 11.24, 'Humidity': 73.8125, 'Pressure': 1025.279468986038, 'UV': 0.1804123711340206, 'AmbientLight': 431.03448275862064}
# time_source 2022-01-06-08-32
# sensor5の分データ {'Temperature': 12.24, 'Humidity': 72.8125, 'Pressure': 1025.2007324330511, 'UV': 0.23195876288659792, 'AmbientLight': 668.103448275862}
# time_source 2022-01-06-08-32
# sensor6の分データ {'Temperature': 11.82, 'Humidity': 72.203125, 'Pressure': 1025.2138551918822, 'UV': 0.1804123711340206, 'AmbientLight': 905.1724137931034}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-11-02
# sensor1の分データ {'Temperature': 23.46, 'Humidity': 57.453125, 'Pressure': 1001.7897306782635, 'UV': 0.9793814432989689, 'AmbientLight': 2241.3793103448274}
# time_source 2022-01-13-11-02
# sensor2の分データ {'Temperature': 27.06, 'Humidity': 47.9375, 'Pressure': 1001.7766079194323, 'UV': 0.8247422680412371, 'AmbientLight': 3534.4827586206893}
# time_source 2022-01-13-11-02
# sensor3の分データ {'Temperature': 26.6, 'Humidity': 51.03125, 'Pressure': 1001.8553444724193, 'UV': 1.1855670103092781, 'AmbientLight': 3275.8620689655168}
# time_source 2022-01-13-11-02
# sensor5の分データ {'Temperature': 24.34, 'Humidity': 51.046875, 'Pressure': 1001.5535210193027, 'UV': 0.747422680412371, 'AmbientLight': 3124.9999999999995}
# time_source 2022-01-13-11-02
# sensor6の分データ {'Temperature': 23.84, 'Humidity': 49.59375, 'Pressure': 1001.8028534370947, 'UV': 0.7989690721649484, 'AmbientLight': 3577.5862068965516}
# no_data
# time_source 2021-12-31-09-24
# sensor1の分データ {'Temperature': 23.28, 'Humidity': 61.59375, 'Pressure': 1011.1462577248799, 'UV': 1.2628865979381443, 'AmbientLight': 3297.413793103448}
# time_source 2021-12-31-09-24
# sensor2の分データ {'Temperature': 22.52, 'Humidity': 63.921875, 'Pressure': 1011.3037308308537, 'UV': 0.6185567010309277, 'AmbientLight': 3146.5517241379307}
# time_source 2021-12-31-09-24
# sensor3の分データ {'Temperature': 24.68, 'Humidity': 65.0625, 'Pressure': 1011.4218356603342, 'UV': 1.0051546391752577, 'AmbientLight': 2456.8965517241377}
# time_source 2021-12-31-09-24
# sensor5の分データ {'Temperature': 25.54, 'Humidity': 62.09375, 'Pressure': 1011.0675211718928, 'UV': 0.9278350515463917, 'AmbientLight': 3620.6896551724135}
# time_source 2021-12-31-09-24
# sensor6の分データ {'Temperature': 21.64, 'Humidity': 65.515625, 'Pressure': 1011.3037308308537, 'UV': 0.6185567010309277, 'AmbientLight': 3232.758620689655}
# no_data
# no_data
# time_source 2022-01-12-00-48
# sensor1の分データ {'Temperature': 10.96, 'Humidity': 97.765625, 'Pressure': 997.5773250934615, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-12-00-48
# sensor2の分データ {'Temperature': 12.76, 'Humidity': 91.140625, 'Pressure': 997.4985885404745, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-08-44
# sensor1の分データ {'Temperature': 19.46, 'Humidity': 71.4375, 'Pressure': 1003.640039673457, 'UV': 1.3659793814432988, 'AmbientLight': 3362.068965517241}
# time_source 2022-01-13-08-44
# sensor2の分データ {'Temperature': 17.1, 'Humidity': 72.421875, 'Pressure': 1003.7056534676127, 'UV': 0.5412371134020618, 'AmbientLight': 2866.3793103448274}
# time_source 2022-01-13-08-44
# sensor3の分データ {'Temperature': 15.14, 'Humidity': 75.59375, 'Pressure': 1003.7975127794308, 'UV': 0.41237113402061853, 'AmbientLight': 1422.4137931034481}
# time_source 2022-01-13-08-44
# sensor5の分データ {'Temperature': 16.24, 'Humidity': 73.703125, 'Pressure': 1003.56130312047, 'UV': 0.5927835051546391, 'AmbientLight': 2176.7241379310344}
# time_source 2022-01-13-08-44
# sensor6の分データ {'Temperature': 20.24, 'Humidity': 68.015625, 'Pressure': 1003.7450217441062, 'UV': 0.6443298969072164, 'AmbientLight': 3146.5517241379307}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2021-12-30-18-35
# sensor1の分データ {'Temperature': 10.8, 'Humidity': 73.859375, 'Pressure': 1006.7107652399482, 'UV': 0.05154639175257732, 'AmbientLight': 0.0}
# time_source 2021-12-30-18-35
# sensor2の分データ {'Temperature': 11.56, 'Humidity': 70.1875, 'Pressure': 1006.6845197222858, 'UV': 0.05154639175257732, 'AmbientLight': 0.0}
# time_source 2021-12-30-18-35
# sensor3の分データ {'Temperature': 10.74, 'Humidity': 71.90625, 'Pressure': 1006.7238879987793, 'UV': 0.07731958762886597, 'AmbientLight': 0.0}
# time_source 2021-12-30-18-35
# sensor5の分データ {'Temperature': 11.26, 'Humidity': 72.125, 'Pressure': 1006.7370107576104, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2021-12-30-18-35
# sensor6の分データ {'Temperature': 10.96, 'Humidity': 71.140625, 'Pressure': 1006.7238879987793, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-02-01-00
# sensor1の分データ {'Temperature': 9.4, 'Humidity': 68.796875, 'Pressure': 1024.373998626688, 'UV': 0.10309278350515463, 'AmbientLight': 21.551724137931032}
# no_data
# time_source 2022-01-12-22-11
# sensor1の分データ {'Temperature': 9.52, 'Humidity': 76.671875, 'Pressure': 1005.9233997100786, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-12-22-11
# sensor2の分データ {'Temperature': 11.14, 'Humidity': 72.015625, 'Pressure': 1005.9365224689097, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# time_source 2022-01-13-07-40
# sensor1の分データ {'Temperature': 11.46, 'Humidity': 79.34375, 'Pressure': 1003.6925307087815, 'UV': 0.07731958762886597, 'AmbientLight': 215.51724137931032}
# time_source 2022-01-13-07-40
# sensor2の分データ {'Temperature': 11.3, 'Humidity': 75.1875, 'Pressure': 1003.7056534676127, 'UV': 0.07731958762886597, 'AmbientLight': 387.9310344827586}
# time_source 2022-01-13-07-40
# sensor3の分データ {'Temperature': 10.7, 'Humidity': 77.875, 'Pressure': 1003.8368810559243, 'UV': 0.12886597938144329, 'AmbientLight': 258.6206896551724}
# time_source 2022-01-13-07-40
# ...
# time_source 2022-01-09-01-37
# sensor5の分データ {'Temperature': 10.06, 'Humidity': 71.21875, 'Pressure': 1018.0225833524071, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-09-01-37
# sensor6の分データ {'Temperature': 10.0, 'Humidity': 70.28125, 'Pressure': 1018.0094605935759, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-10-03
# sensor1の分データ {'Temperature': 22.24, 'Humidity': 62.21875, 'Pressure': 1002.9707789730678, 'UV': 0.9278350515463917, 'AmbientLight': 2413.793103448276}
# time_source 2022-01-13-10-03
# sensor2の分データ {'Temperature': 25.96, 'Humidity': 58.015625, 'Pressure': 1003.0495155260547, 'UV': 0.8247422680412371, 'AmbientLight': 3749.9999999999995}
# time_source 2022-01-13-10-03
# sensor3の分データ {'Temperature': 24.52, 'Humidity': 60.578125, 'Pressure': 1003.1282520790418, 'UV': 0.9793814432989689, 'AmbientLight': 2995.6896551724135}
# time_source 2022-01-13-10-03
# sensor5の分データ {'Temperature': 23.66, 'Humidity': 57.5, 'Pressure': 1002.813305867094, 'UV': 0.902061855670103, 'AmbientLight': 3534.4827586206893}
# time_source 2022-01-13-10-03
# sensor6の分データ {'Temperature': 21.74, 'Humidity': 59.875, 'Pressure': 1003.0626382848859, 'UV': 0.6958762886597938, 'AmbientLight': 3512.931034482758}
# no_data
# no_data
# no_data
# time_source 2022-01-13-17-41
# sensor1の分データ {'Temperature': 11.22, 'Humidity': 79.34375, 'Pressure': 998.4565499351492, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2022-01-13-17-41
# sensor2の分データ {'Temperature': 11.7, 'Humidity': 75.40625, 'Pressure': 998.3646906233311, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# no_data
# time_source 2021-12-17-17-06
# sensor1の分データ {'Temperature': 12.0, 'Humidity': 92.90625, 'Pressure': 994.0997940032044, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2021-12-17-17-06
# sensor2の分データ {'Temperature': 12.06, 'Humidity': 91.3125, 'Pressure': 994.0866712443733, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2021-12-17-17-06
# sensor3の分データ {'Temperature': 11.72, 'Humidity': 91.671875, 'Pressure': 994.1129167620355, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2021-12-17-17-06
# sensor5の分データ {'Temperature': 12.48, 'Humidity': 93.125, 'Pressure': 994.1785305561914, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2021-12-17-17-06
# sensor6の分データ {'Temperature': 11.68, 'Humidity': 91.671875, 'Pressure': 994.0866712443733, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# time_source 2022-01-12-09-03
# sensor1の分データ {'Temperature': 24.62, 'Humidity': 69.109375, 'Pressure': 1002.157167925536, 'UV': 1.4432989690721647, 'AmbientLight': 3469.8275862068963}
# time_source 2022-01-12-09-03
# sensor2の分データ {'Temperature': 20.52, 'Humidity': 74.359375, 'Pressure': 1002.2490272373541, 'UV': 0.6443298969072164, 'AmbientLight': 3124.9999999999995}
# no_data
# time_source 2022-01-11-01-41
# sensor1の分データ {'Temperature': 9.88, 'Humidity': 92.84375, 'Pressure': 1017.0252536812391, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-11-01-41
# sensor2の分データ {'Temperature': 10.58, 'Humidity': 89.203125, 'Pressure': 1016.9202716105898, 'UV': 1.0309278350515463, 'AmbientLight': 0.0}
# time_source 2022-01-11-01-41
# sensor3の分データ {'Temperature': 9.78, 'Humidity': 89.328125, 'Pressure': 1017.0252536812391, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-11-01-41
# sensor5の分データ {'Temperature': 10.9, 'Humidity': 89.875, 'Pressure': 1017.0908674753948, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-11-01-41
# sensor6の分データ {'Temperature': 10.24, 'Humidity': 88.53125, 'Pressure': 1017.0383764400702, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-02-51
# sensor1の分データ {'Temperature': 9.62, 'Humidity': 95.78125, 'Pressure': 998.9552147707332, 'UV': 0.05154639175257732, 'AmbientLight': 0.0}
# time_source 2022-01-12-02-51
# sensor2の分データ {'Temperature': 11.38, 'Humidity': 89.40625, 'Pressure': 998.8633554589151, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-06-34
# sensor1の分データ {'Temperature': 9.5, 'Humidity': 90.546875, 'Pressure': 1000.6611734187838, 'UV': 0.05154639175257732, 'AmbientLight': 64.6551724137931}
# time_source 2022-01-12-06-34
# sensor2の分データ {'Temperature': 11.32, 'Humidity': 83.65625, 'Pressure': 1000.6218051422903, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-03-44
# sensor1の分データ {'Temperature': 9.82, 'Humidity': 94.6875, 'Pressure': 999.4538796063173, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-12-03-44
# sensor2の分データ {'Temperature': 11.5, 'Humidity': 88.15625, 'Pressure': 999.3882658121614, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-11-23-50
# sensor1の分データ {'Temperature': 11.08, 'Humidity': 99.890625, 'Pressure': 997.0261692225529, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2022-01-11-23-50
# sensor2の分データ {'Temperature': 12.96, 'Humidity': 93.5625, 'Pressure': 996.9999237048905, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# time_source 2022-01-13-17-30
# sensor1の分データ {'Temperature': 10.72, 'Humidity': 79.921875, 'Pressure': 998.2334630350194, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-13-17-30
# sensor2の分データ {'Temperature': 11.72, 'Humidity': 76.84375, 'Pressure': 998.1547264820325, 'UV': 0.05154639175257732, 'AmbientLight': 21.551724137931032}
# no_data
# time_source 2022-01-13-15-23
# sensor1の分データ {'Temperature': 18.46, 'Humidity': 53.734375, 'Pressure': 996.6981002517739, 'UV': 0.5412371134020618, 'AmbientLight': 1185.3448275862067}
# time_source 2022-01-13-15-23
# sensor2の分データ {'Temperature': 27.04, 'Humidity': 42.75, 'Pressure': 996.789959563592, 'UV': 1.1597938144329896, 'AmbientLight': 4137.931034482758}
# time_source 2022-01-13-15-23
# sensor3の分データ {'Temperature': 17.2, 'Humidity': 54.40625, 'Pressure': 996.789959563592, 'UV': 0.3092783505154639, 'AmbientLight': 905.1724137931034}
# time_source 2022-01-13-15-23
# sensor5の分データ {'Temperature': 19.72, 'Humidity': 51.15625, 'Pressure': 996.6062409399558, 'UV': 0.46391752577319584, 'AmbientLight': 1443.9655172413793}
# time_source 2022-01-13-15-23
# sensor6の分データ {'Temperature': 19.88, 'Humidity': 47.21875, 'Pressure': 996.7505912870985, 'UV': 0.46391752577319584, 'AmbientLight': 2262.9310344827586}
# no_data
# time_source 2022-01-09-21-20
# sensor1の分データ {'Temperature': 11.44, 'Humidity': 82.828125, 'Pressure': 1018.0094605935759, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-09-21-20
# sensor2の分データ {'Temperature': 12.38, 'Humidity': 79.390625, 'Pressure': 1017.9438467994202, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-09-21-20
# sensor3の分データ {'Temperature': 11.22, 'Humidity': 80.59375, 'Pressure': 1017.9832150759137, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2022-01-09-21-20
# sensor5の分データ {'Temperature': 12.36, 'Humidity': 81.15625, 'Pressure': 1017.9963378347447, 'UV': 0.05154639175257732, 'AmbientLight': 0.0}
# time_source 2022-01-09-21-20
# sensor6の分データ {'Temperature': 11.88, 'Humidity': 80.75, 'Pressure': 1017.9700923170825, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-08-00-03
# sensor1の分データ {'Temperature': 8.74, 'Humidity': 74.109375, 'Pressure': 1022.3137254901961, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-08-00-03
# sensor2の分データ {'Temperature': 10.36, 'Humidity': 68.875, 'Pressure': 1022.2087434195469, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-08-00-03
# sensor3の分データ {'Temperature': 8.76, 'Humidity': 72.3125, 'Pressure': 1022.300602731365, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-08-00-03
# sensor5の分データ {'Temperature': 10.24, 'Humidity': 70.5625, 'Pressure': 1022.3662165255207, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-08-00-03
# sensor6の分データ {'Temperature': 10.0, 'Humidity': 69.375, 'Pressure': 1022.3399710078584, 'UV': 0.05154639175257732, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-12-10-02
# sensor1の分データ {'Temperature': 23.1, 'Humidity': 65.640625, 'Pressure': 1002.5114824139773, 'UV': 0.9536082474226804, 'AmbientLight': 2435.3448275862065}
# time_source 2022-01-12-10-02
# sensor2の分データ {'Temperature': 26.68, 'Humidity': 61.671875, 'Pressure': 1002.6033417257954, 'UV': 0.9793814432989689, 'AmbientLight': 3900.8620689655168}
# no_data
# time_source 2022-01-12-01-52
# sensor1の分データ {'Temperature': 9.62, 'Humidity': 95.09375, 'Pressure': 998.2072175173571, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-12-01-52
# sensor2の分データ {'Temperature': 11.0, 'Humidity': 89.15625, 'Pressure': 998.2203402761883, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# no_data
# time_source 2022-01-13-13-31
# sensor1の分データ {'Temperature': 18.28, 'Humidity': 51.34375, 'Pressure': 998.0497444113832, 'UV': 0.8505154639175256, 'AmbientLight': 1982.7586206896551}
# time_source 2022-01-13-13-31
# sensor2の分データ {'Temperature': 21.36, 'Humidity': 42.75, 'Pressure': 997.866025787747, 'UV': 1.0567010309278349, 'AmbientLight': 3857.758620689655}
# time_source 2022-01-13-13-31
# sensor3の分データ {'Temperature': 17.52, 'Humidity': 49.203125, 'Pressure': 997.9972533760586, 'UV': 0.7216494845360824, 'AmbientLight': 1982.7586206896551}
# time_source 2022-01-13-13-31
# sensor5の分データ {'Temperature': 18.8, 'Humidity': 44.640625, 'Pressure': 997.7741664759288, 'UV': 0.6443298969072164, 'AmbientLight': 2370.6896551724135}
# time_source 2022-01-13-13-31
# sensor6の分データ {'Temperature': 20.82, 'Humidity': 41.359375, 'Pressure': 997.9316395819028, 'UV': 0.902061855670103, 'AmbientLight': 4159.482758620689}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-13-02-10
# sensor1の分データ {'Temperature': 9.02, 'Humidity': 77.390625, 'Pressure': 1005.3328755626765, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-13-02-10
# sensor2の分データ {'Temperature': 10.52, 'Humidity': 72.359375, 'Pressure': 1005.2672617685206, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-09-17-24
# sensor1の分データ {'Temperature': 11.54, 'Humidity': 70.921875, 'Pressure': 1015.5292591744869, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-09-17-24
# sensor2の分データ {'Temperature': 11.6, 'Humidity': 68.375, 'Pressure': 1015.4373998626688, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# time_source 2022-01-09-17-24
# sensor3の分データ {'Temperature': 11.34, 'Humidity': 70.53125, 'Pressure': 1015.4767681391622, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-09-17-24
# sensor5の分データ {'Temperature': 12.48, 'Humidity': 70.5, 'Pressure': 1015.5948729686427, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-09-17-24
# sensor6の分データ {'Temperature': 11.3, 'Humidity': 69.921875, 'Pressure': 1015.5686274509804, 'UV': 0.0, 'AmbientLight': 43.103448275862064}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-06-23
# sensor1の分データ {'Temperature': 9.0, 'Humidity': 91.109375, 'Pressure': 1000.6218051422903, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-12-06-23
# sensor2の分データ {'Temperature': 10.6, 'Humidity': 84.484375, 'Pressure': 1000.5693141069657, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-12-00-16
# sensor1の分データ {'Temperature': 10.18, 'Humidity': 97.71875, 'Pressure': 997.1836423285267, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-12-00-16
# sensor2の分データ {'Temperature': 11.44, 'Humidity': 91.765625, 'Pressure': 997.1573968108644, 'UV': 0.0, 'AmbientLight': 237.06896551724137}
# no_data
# time_source 2022-01-13-14-51
# sensor1の分データ {'Temperature': 19.42, 'Humidity': 51.59375, 'Pressure': 996.8030823224232, 'UV': 0.9278350515463917, 'AmbientLight': 2219.8275862068963}
# time_source 2022-01-13-14-51
# sensor2の分データ {'Temperature': 21.0, 'Humidity': 44.09375, 'Pressure': 996.789959563592, 'UV': 0.7989690721649484, 'AmbientLight': 3297.413793103448}
# time_source 2022-01-13-14-51
# sensor3の分データ {'Temperature': 16.86, 'Humidity': 51.34375, 'Pressure': 996.8555733577477, 'UV': 0.41237113402061853, 'AmbientLight': 1271.551724137931}
# time_source 2022-01-13-14-51
# sensor5の分データ {'Temperature': 18.58, 'Humidity': 48.40625, 'Pressure': 996.6456092164492, 'UV': 0.46391752577319584, 'AmbientLight': 1918.1034482758619}
# time_source 2022-01-13-14-51
# sensor6の分データ {'Temperature': 21.28, 'Humidity': 42.28125, 'Pressure': 996.789959563592, 'UV': 0.6701030927835051, 'AmbientLight': 3297.413793103448}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2021-12-29-05-13
# sensor1の分データ {'Temperature': 10.0, 'Humidity': 75.171875, 'Pressure': 1024.2165255207142, 'UV': 0.07731958762886597, 'AmbientLight': 0.0}
# time_source 2021-12-29-05-13
# sensor2の分データ {'Temperature': 11.22, 'Humidity': 70.375, 'Pressure': 1024.124666208896, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2021-12-29-05-13
# sensor3の分データ {'Temperature': 9.98, 'Humidity': 73.5, 'Pressure': 1024.295262073701, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2021-12-29-05-13
# sensor5の分データ {'Temperature': 11.14, 'Humidity': 73.25, 'Pressure': 1024.1509117265582, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2021-12-29-05-13
# sensor6の分データ {'Temperature': 10.86, 'Humidity': 71.1875, 'Pressure': 1024.2427710383763, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# no_data
# no_data
# time_source 2022-01-08-18-07
# sensor1の分データ {'Temperature': 9.72, 'Humidity': 74.96875, 'Pressure': 1020.9489585717555, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-08-18-07
# sensor2の分データ {'Temperature': 10.76, 'Humidity': 70.578125, 'Pressure': 1020.8308537422752, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-08-18-07
# sensor3の分データ {'Temperature': 9.54, 'Humidity': 73.15625, 'Pressure': 1020.9095902952621, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-08-18-07
# sensor5の分データ {'Temperature': 10.82, 'Humidity': 72.421875, 'Pressure': 1020.9752040894178, 'UV': 0.02577319587628866, 'AmbientLight': 0.0}
# time_source 2022-01-08-18-07
# sensor6の分データ {'Temperature': 10.28, 'Humidity': 71.171875, 'Pressure': 1020.8702220187686, 'UV': 0.0, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-13-10-51
# sensor1の分データ {'Temperature': 21.02, 'Humidity': 60.265625, 'Pressure': 1002.0915541313802, 'UV': 0.8505154639175256, 'AmbientLight': 2219.8275862068963}
# time_source 2022-01-13-10-51
# sensor2の分データ {'Temperature': 27.46, 'Humidity': 49.875, 'Pressure': 1002.1046768902113, 'UV': 0.8505154639175256, 'AmbientLight': 3556.0344827586205}
# time_source 2022-01-13-10-51
# sensor3の分データ {'Temperature': 26.08, 'Humidity': 53.359375, 'Pressure': 1002.2227817196917, 'UV': 1.1597938144329896, 'AmbientLight': 3362.068965517241}
# time_source 2022-01-13-10-51
# sensor5の分データ {'Temperature': 25.1, 'Humidity': 53.21875, 'Pressure': 1001.8684672312505, 'UV': 0.9278350515463917, 'AmbientLight': 3512.931034482758}
# time_source 2022-01-13-10-51
# sensor6の分データ {'Temperature': 22.08, 'Humidity': 54.09375, 'Pressure': 1002.0653086137179, 'UV': 0.7731958762886597, 'AmbientLight': 3620.6896551724135}
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# no_data
# time_source 2022-01-11-03-37
# sensor1の分データ {'Temperature': 11.04, 'Humidity': 93.4375, 'Pressure': 1015.8442053864347, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-11-03-37
# sensor2の分データ {'Temperature': 12.36, 'Humidity': 89.21875, 'Pressure': 1015.8048371099412, 'UV': 0.02577319587628866, 'AmbientLight': 21.551724137931032}
# time_source 2022-01-11-03-37
# sensor3の分データ {'Temperature': 10.8, 'Humidity': 90.15625, 'Pressure': 1015.8835736629283, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-11-03-37
# sensor5の分データ {'Temperature': 12.16, 'Humidity': 90.875, 'Pressure': 1015.8573281452659, 'UV': 0.0, 'AmbientLight': 0.0}
# time_source 2022-01-11-03-37
# sensor6の分データ {'Temperature': 11.7, 'Humidity': 89.234375, 'Pressure': 1015.8310826276036, 'UV': 0.0, 'AmbientLight': 0.0}
# no_data
# 185

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
        ])
        self.data_num = len(tdata)
    def __len__(self):
        return self.data_num
    def __getitem__(self, idx):
        image = Image.open(fdata[idx])
#        if self.transform:
#            out_data = self.transform(image)
        out_data = np.array(image).reshape(16*18).astype(np.int32) 
        out_data = out_data*50/255
        return torch.Tensor(sdata[idx]), torch.Tensor(out_data) 
data_set = MyDataset()

# %%
def heatmapshow(data):
    im = Image.fromarray(data[0].numpy().reshape([16,18]).copy()*255/50)
    fig, ax = plt.subplots()
    ax.imshow(im, cmap="gray")
    plt.show()

# %%
train_size = len(data_set)*0.8
train_size
# Out:
# 148.0

# %%
from torch.utils.data.dataset import Subset
def split_dataset(data_set, split_at, order=None):
    from torch.utils.data.dataset import Subset
    n_examples = len(data_set)
    if split_at < 0:
        raise ValueError('split_at must be non-negative')
    if split_at > n_examples:
        raise ValueError('split_at exceeds the dataset size')
    if order is not None:
        subset1_indices = order[0:split_at]
        subset2_indices = order[split_at:n_examples]
    else:
        subset1_indices = list(range(0,split_at))
        subset2_indices = list(range(split_at,n_examples))

    subset1 = Subset(data_set, subset1_indices)
    subset2 = Subset(data_set, subset2_indices)
    return subset1, subset2

def split_dataset_random(data_set, first_size, seed=0):
    order = np.random.RandomState(seed).permutation(len(data_set))
    return split_dataset(data_set, int(first_size), order)

# %%
test_dataset, data_set = split_dataset_random(data_set, testsize, seed=0)
train_dataset, val_dataset = split_dataset_random(data_set, train_size, seed=0)

test_loader = DataLoader(dataset=test_dataset, batch_size=1, shuffle=False)
train_loader = DataLoader(dataset=data_set, batch_size=batchsize, shuffle=True)
val_loader = DataLoader(dataset=data_set, batch_size=batchsize, shuffle=False)
# Out:
# 10
# 175

# %%
class NET(nn.Module):
    def __init__(self):
        super(NET, self).__init__()
        self.fc1 = nn.Linear(xsize, 128)
        self.fc2 = nn.Linear(128, 256)
        self.fc3 = nn.Linear(256, 256)
        self.fc4 = nn.Linear(256, 13*15)
        self.conv = nn.Sequential(
            torch.nn.ConvTranspose2d(1, 1, kernel_size=(4, 4),  stride=(1, 1)),
            torch.nn.ReLU(),
        )
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        x = x.view(x.size(0), 1, 13, 15)
        x = self.conv(x)
        return x
model = NET().to(device)
model
# Out:
# NET(
#   (fc1): Linear(in_features=5, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=195, bias=True)
#   (conv): Sequential(
#     (0): ConvTranspose2d(1, 1, kernel_size=(4, 4), stride=(1, 1))
#     (1): ReLU()
#   )
# )

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
train_loss_list = []
val_loss_list = []
for epoch in range(epochs):
    
    model.train()
    train_running_loss = 0
    for batch_idx, (x, c) in enumerate(train_loader):
        x = x.to(device)
        c = c.to(device)
        optimizer.zero_grad()
        y = model(x)

        c = c.view(x.size(0), 1, 16, 18)
        train_loss = criterion(y, c)
        train_running_loss += train_loss.item()
        train_loss.backward()
        optimizer.step()
    train_loss_list.append(train_loss)
    train_loss = train_running_loss / len(train_loader) 
    
    model.eval()
    val_running_loss = 0
    with torch.no_grad():
        for batch_idx, (x, c) in enumerate(val_loader):
            x = x.to(device)
            c = c.to(device)
            c = c.view(x.size(0), 1, 16, 18)
            y = model(x)
            val_loss = criterion(y, c)
            val_running_loss += val_loss.item()
        val_loss_list.append(val_loss)

    if epoch == 0:
        best_epoch = epoch
        torch.save(model.state_dict(), 'model.pth')
        best_valid_loss = val_running_loss
    else:
        if best_valid_loss > val_running_loss:
            torch.save(model.state_dict(), f"model{epoch}.pth")
            best_valid_loss = val_running_loss
            best_epoch = epoch

    val_loss = val_running_loss / len(val_loader)  
    print('epoch %d, loss: %.4f val_loss: %.4f' % (epoch, train_loss, val_loss))
    
print('best_epoch', best_epoch)
# Out:
# epoch 0, loss: 530.6048 val_loss: 524.6457
# epoch 1, loss: 520.2870 val_loss: 506.9620
# epoch 2, loss: 498.3290 val_loss: 480.1584
# epoch 3, loss: 470.2938 val_loss: 444.0362
# epoch 4, loss: 433.3066 val_loss: 402.7486
# epoch 5, loss: 393.9015 val_loss: 367.4427
# epoch 6, loss: 360.5704 val_loss: 355.1309
# epoch 7, loss: 353.5042 val_loss: 359.2634
# epoch 8, loss: 354.9845 val_loss: 348.2489
# epoch 9, loss: 341.5436 val_loss: 329.9398
# epoch 10, loss: 324.5507 val_loss: 320.8293
# epoch 11, loss: 320.1657 val_loss: 319.7719
# epoch 12, loss: 318.5604 val_loss: 319.8908
# epoch 13, loss: 317.3058 val_loss: 317.9738
# epoch 14, loss: 316.7442 val_loss: 314.5809
# epoch 15, loss: 312.5975 val_loss: 311.5794
# epoch 16, loss: 311.5795 val_loss: 310.0559
# epoch 17, loss: 308.4863 val_loss: 308.7713
# epoch 18, loss: 310.1085 val_loss: 306.4701
# epoch 19, loss: 304.8844 val_loss: 303.4228
# epoch 20, loss: 302.1551 val_loss: 301.3176
# epoch 21, loss: 301.4477 val_loss: 300.4667
# epoch 22, loss: 299.8757 val_loss: 299.4886
# epoch 23, loss: 298.3058 val_loss: 298.0027
# epoch 4987, loss: 53.1261 val_loss: 52.8409
# epoch 4988, loss: 53.3466 val_loss: 53.0649
# epoch 4989, loss: 53.1755 val_loss: 52.9806
# epoch 4990, loss: 53.1538 val_loss: 52.8798
# epoch 4991, loss: 53.4485 val_loss: 53.0307
# epoch 4992, loss: 52.6488 val_loss: 52.9681
# epoch 4993, loss: 52.4793 val_loss: 52.8669
# epoch 4994, loss: 53.0937 val_loss: 52.9021
# epoch 4995, loss: 52.9800 val_loss: 52.9803
# epoch 4996, loss: 53.1074 val_loss: 52.8662
# epoch 4997, loss: 53.3353 val_loss: 53.3678
# epoch 4998, loss: 53.0013 val_loss: 53.9170
# epoch 4999, loss: 54.3340 val_loss: 54.1121
# best_epoch 4987

# %%
print(best_epoch)
# Out:
# 4987

# %%
train_loss_list = torch.tensor(train_loss_list)
val_loss_list = torch.tensor(val_loss_list)

plt.plot(range(len(train_loss_list)), train_loss_list, label="Train")
plt.plot(range(len(val_loss_list)), val_loss_list, label="Test")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Error")
plt.show()

# %%
plt.xlim(0, 3000)
plt.plot(range(len(train_loss_list)), train_loss_list, label="Train")
plt.plot(range(len(val_loss_list)), val_loss_list, label="Test")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Error")
plt.show()

# %%
valid_net = NET().to(device)
valid_net.eval()
valid_net.load_state_dict(torch.load('model' + str(best_epoch) +'.pth'))
# Out:
# <All keys matched successfully>

# %%
import seaborn
def test():
    test_net.eval()
    running_loss = 0
    with torch.no_grad():
        total_max_temp_error = 0
        total_min_temp_error = 0
        max_error_x = 0
        max_error_y = 0
        min_error_x = 0
        min_error_y = 0
        error_per_pix = 0
        loss_sum = 0
        max_error_x_abs = 0
        max_error_y_abs = 0
        min_error_x_abs = 0
        min_error_y_abs = 0
            
        estimate_list = []

        for batch_idx, (x, c) in enumerate(test_loader):
            estimate_start = time.time()
            print('=================================')
            x, c = tmp.next()
            x = x.to(device)
            c = c.to(device)
            y = model(x)
            estimate_end = time.time()
            estimate_duration = -estimate_start+estimate_end
            print("{}個目のモデルの推定時間は：{}秒です".format(batch_idx+1, estimate_duration))
            estimate_list.append(estimate_duration)
            continue
            loss = criterion(y, c)
            loss_unit = torch.sum(torch.abs(y-c))/16/18
            loss_sum = loss_sum + loss_unit
            running_loss += loss.item()
            
            
            y = y.cpu()
            c = c.cpu()
            c_reshaped = c.reshape(16, 18)
            seaborn.heatmap(c_reshaped, vmin=18, vmax=25)
            plt.show()
            y_reshaped = y.reshape(16, 18)
            seaborn.heatmap(y_reshaped, vmin=18, vmax=25)
            plt.show()
            
            #最高温度のずれ
            max_temp_output = torch.max(c)
            max_temp_target = torch.max(y)
            max_temp_error = max_temp_output - max_temp_target
            total_max_temp_error = total_max_temp_error + max_temp_error

            #最低温度のずれ
            min_temp_output = torch.min(c)
            min_temp_target = torch.min(y)
            min_temp_error = min_temp_output - min_temp_target
            total_min_temp_error = total_min_temp_error + min_temp_error

            #最高温度を示すピクセルの座標のずれ(絶対値)
            max_temp_arg = torch.argmax(c)
            max_x_output = (max_temp_arg + 1)%18 -1
            max_y_output = -(max_temp_arg + 1)//18

            max_temp_arg = torch.argmax(y)
            max_x_target = (max_temp_arg + 1)%18 -1
            max_y_target = -(max_temp_arg + 1)//18
            
            max_error_x = max_error_x + abs(max_x_output - max_x_target)
            max_error_y = max_error_y + abs(max_y_output - max_y_target)

            # 最低温度を示すピクセルの座標のずれ(絶対値)
            min_temp_arg = torch.argmin(c)
            min_x_output = (min_temp_arg + 1)%18 -1
            min_y_output = -(min_temp_arg + 1)//18

            min_temp_arg = torch.argmin(y)
            min_x_target = (min_temp_arg + 1)%18 -1
            min_y_target = -(min_temp_arg + 1)//18
            
            min_error_x = min_error_x + abs(min_x_output - min_x_target)
            min_error_y = min_error_y + abs(min_y_output - min_y_target)

    print("平均時間は{}秒です".format(sum(estimate_list)/len(estimate_list)))
    return 0

    print('1ピクセルあたりの誤差', loss_sum/len(test_loader))
    print('最高温度のずれ', total_max_temp_error/len(test_loader))      
    print('最低温度のずれ', total_min_temp_error/len(test_loader))
    print('最高温度を示すピクセルの座標のずれ', max_error_x_abs/len(test_loader), max_error_y_abs/len(test_loader), )
    print('最低温度を示すピクセルの座標のずれ', min_error_x_abs/len(test_loader), min_error_y_abs/len(test_loader), )
    
    print("batch_size: {}　です。頑張ってください".format(batchsize))
    print(fpath)
    p = [loss_sum/len(test_loader), total_max_temp_error/len(test_loader), total_min_temp_error/len(test_loader), max_error_x/len(test_loader), max_error_y/len(test_loader), min_error_x/len(test_loader), min_error_y/len(test_loader), max_error_x_abs/len(test_loader), max_error_y_abs/len(test_loader), min_error_x_abs/len(test_loader), min_error_y_abs/len(test_loader), best_epoch]
    p = [float(x) for x in p]
    p.insert(0, "条件"+str(histwindow))
    print(*p, sep=', ')

    val_loss = running_loss / len(test_loader)

# %%
test()
# Out:
# =================================
# =================================
# /tmp/ipykernel_552317/2405074226.py:60: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_x_output = (max_temp_arg + 1)//18
# /tmp/ipykernel_552317/2405074226.py:64: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_x_target = (max_temp_arg + 1)//18
# /tmp/ipykernel_552317/2405074226.py:75: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   min_x_output = (min_temp_arg + 1)//18
# /tmp/ipykernel_552317/2405074226.py:79: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   min_x_target = (min_temp_arg + 1)//18
# /tmp/ipykernel_552317/2405074226.py:88: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_x_output_abs = (max_temp_arg_abs + 1)//18
# /tmp/ipykernel_552317/2405074226.py:92: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_x_target_abs = (max_temp_arg_abs + 1)//18
# /tmp/ipykernel_552317/2405074226.py:99: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   min_x_output_abs = (min_temp_arg_abs + 1)//18
# /tmp/ipykernel_552317/2405074226.py:103: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   min_x_target_abs = (min_temp_arg_abs + 1)//18
# =================================
# =================================
# =================================
# =================================
# =================================
# =================================
# =================================
# =================================
# 1ピクセルあたりの誤差 tensor(8.9365, device='cuda:2')
# 最高温度のずれ tensor(0.5007)
# 最低温度のずれ tensor(13.2353)
# 最高温度を示すピクセルの座標のずれ tensor(-0.1000) tensor(4.9000)
# 最低温度を示すピクセルの座標のずれ tensor(7.5000) tensor(3.1000)
# abs最高温度を示すピクセルの座標のずれ tensor(5.9000) tensor(5.5000)
# abs最低温度を示すピクセルの座標のずれ tensor(7.5000) tensor(3.5000)
