# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from torchvision.datasets import CIFAR10
import numpy as np
import matplotlib.pyplot as plt
import json
from datetime import datetime, timedelta
import os
from PIL import Image
if torch.cuda.is_available():
    print(torch.cuda.device_count())
device = torch.device("cuda:0")
print(device)
# Out:
# 3
# cuda:0

# %%
import glob
import re
import json
from pathlib import Path
np.random.seed(1)
torch.manual_seed(1)
torch.cuda.manual_seed(1)

# %%
histwindow = 1 
batchsize = 100
testsize = 10
epochs = 500
allsensors = ('sensor1', 'sensor2', 'sensor3', 'sensor5', 'sensor6')
fpath = '/proj/NARO/sonoda/noken/noken_0_50_selected'

# %%
alldata = {}
def sensdata(name):
    jso = open("../sonoda/{}/all.json".format(name))
    jsl = json.load(jso)
    alldata[name] = jsl
for sname in allsensors:
    sensdata(sname)

# %%
files = glob.glob(fpath+'/*.jpg')
sdata = []
fdata = []
tdata = []

for file in files:#全ヒートマップについて
    reres = re.findall('.*/data_(20\d\d)(\d\d)(\d\d)_(\d\d)(\d\d)(\d\d).jpg', file)
    (year, month, day, hour, minute, sec) = reres[0]
    dt_date = datetime(int(year), int(month), int(day), int(hour), int(minute), int(sec))
    dt_epoch = int((dt_date.timestamp()+30)/60)*60
    dt_adj = datetime.fromtimestamp(dt_epoch)
    dt_prev = dt_adj
    time_adj = dt_adj.strftime('%Y-%m-%d-%H-%M')
    time_prev = time_adj
    sensd = []
    histerr = 0
    for hist in range(0, histwindow):
        for sname in allsensors:
            if alldata[sname].get(time_prev):
                sensd.append(alldata[sname][time_prev]['Temperature'])
            else:
                histerr = 1
                break
        if histerr:
            break
        dt_prev = dt_prev - timedelta(minutes=1)
        time_prev = dt_prev.strftime('%Y-%m-%d-%H-%M')
    if not histerr:
        sdata.append(sensd)
        tdata.append(time_adj)
        fdata.append(file)

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
        ])
        self.data_num = len(tdata)
    def __len__(self):
        return self.data_num
    def __getitem__(self, idx):
        image = Image.open(fdata[idx])
#        if self.transform:
#            out_data = self.transform(image)
        out_data = np.array(image).reshape(16*18).astype(np.int32)
        out_data = out_data*50/255
        return torch.Tensor(sdata[idx]), torch.Tensor(out_data) 
data_set = MyDataset()

# %%
def heatmapshow(data):
    im = Image.fromarray(data[0].numpy().reshape([16,18]).copy()*255/50)
    fig, ax = plt.subplots()
    ax.imshow(im, cmap="gray")
    plt.show()

# %%
train_size = len(data_set)*0.8
train_size
# Out:
# 150.4

# %%
from torch.utils.data.dataset import Subset
def split_dataset(data_set, split_at, order=None):
    from torch.utils.data.dataset import Subset
    n_examples = len(data_set)
    if split_at < 0:
        raise ValueError('split_at must be non-negative')
    if split_at > n_examples:
        raise ValueError('split_at exceeds the dataset size')
    if order is not None:
        subset1_indices = order[0:split_at]
        subset2_indices = order[split_at:n_examples]
    else:
        subset1_indices = list(range(0,split_at))
        subset2_indices = list(range(split_at,n_examples))

    subset1 = Subset(data_set, subset1_indices)
    subset2 = Subset(data_set, subset2_indices)
    return subset1, subset2

def split_dataset_random(data_set, first_size, seed=0):
    order = np.random.RandomState(seed).permutation(len(data_set))
    return split_dataset(data_set, int(first_size), order)

# %%
test_dataset, data_set = split_dataset_random(data_set, testsize, seed=33)
train_dataset, val_dataset = split_dataset_random(data_set, train_size, seed=0)

test_loader = DataLoader(dataset=test_dataset, batch_size=1, shuffle=False)
train_loader = DataLoader(dataset=data_set, batch_size=batchsize, shuffle=True)
val_loader = DataLoader(dataset=data_set, batch_size=batchsize, shuffle=False)
# Out:
# 10
# 178

# %%
class NET(nn.Module):
    def __init__(self):
        super(NET, self).__init__()
        self.fc1 = nn.Linear(xsize, 128)
        self.fc2 = nn.Linear(128, 256)
        self.fc3 = nn.Linear(256, 256)
        self.fc4 = nn.Linear(256, 16*18)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x
model = NET().to(device)
model
# Out:
# NET(
#   (fc1): Linear(in_features=5, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=288, bias=True)
# )

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.3)

# %%
train_loss_list = []
val_loss_list = []
for epoch in range(epochs):
    
    model.train()
    train_running_loss = 0
    for batch_idx, (x, c) in enumerate(train_loader):
        x = x.to(device)
        c = c.to(device)
        optimizer.zero_grad()
        y = model(x)
        train_loss = criterion(y, c)
        train_running_loss += train_loss.item()
        train_loss.backward()
        optimizer.step()
    train_loss_list.append(train_loss)
    train_loss = train_running_loss / len(train_loader) 
    
    model.eval()
    val_running_loss = 0
    with torch.no_grad():
        for batch_idx, (x, c) in enumerate(val_loader):
            x = x.to(device)
            c = c.to(device)
            y = model(x)
            val_loss = criterion(y, c)
            val_running_loss += val_loss.item()
        val_loss_list.append(val_loss)

    if epoch == 0:
        best_epoch = epoch
        torch.save(model.state_dict(), 'model.pth')
        best_valid_loss = val_running_loss
    else:
        if best_valid_loss > val_running_loss:
            torch.save(model.state_dict(), f"model{epoch}.pth")
            best_valid_loss = val_running_loss
            best_epoch = epoch

    val_loss = val_running_loss / len(val_loader)  
    print('epoch %d, loss: %.4f val_loss: %.4f' % (epoch, train_loss, val_loss))
    
print('best_epoch', best_epoch)
# Out:
# epoch 0, loss: 5883822351.1873 val_loss: 12218090.0000
# epoch 1, loss: 6271303.0391 val_loss: 61401.7637
# epoch 2, loss: 29506.8692 val_loss: 870301.9688
# epoch 3, loss: 698701.1406 val_loss: 501329.9844
# epoch 4, loss: 288770.3359 val_loss: 173.5034
# epoch 5, loss: 2935.5422 val_loss: 291.7458
# epoch 6, loss: 9925.8145 val_loss: 2221.8121
# epoch 7, loss: 8869.3279 val_loss: 6905.3511
# epoch 8, loss: 3765.3901 val_loss: 9131.3853
# epoch 9, loss: 8605.5557 val_loss: 696.0768
# epoch 10, loss: 1424.8491 val_loss: 6537.4807
# epoch 11, loss: 5853.5940 val_loss: 1241.0608
# epoch 12, loss: 785.5602 val_loss: 2395.6166
# epoch 13, loss: 2832.7804 val_loss: 2132.7865
# epoch 14, loss: 1251.9717 val_loss: 154.9391
# epoch 15, loss: 531.7227 val_loss: 1641.2877
# epoch 16, loss: 1597.3628 val_loss: 906.3986
# epoch 17, loss: 593.4248 val_loss: 104.1740
# epoch 18, loss: 249.9953 val_loss: 695.6613
# epoch 19, loss: 732.3968 val_loss: 583.2311
# epoch 20, loss: 436.0839 val_loss: 118.1482
# epoch 21, loss: 119.4409 val_loss: 236.1960
# epoch 22, loss: 294.8699 val_loss: 396.3060
# epoch 23, loss: 368.1268 val_loss: 225.0943
# epoch 24, loss: 179.1459 val_loss: 92.1638
# epoch 25, loss: 113.8176 val_loss: 170.2308
# epoch 26, loss: 187.3358 val_loss: 209.8716
# epoch 27, loss: 193.9134 val_loss: 132.4173
# epoch 28, loss: 115.2888 val_loss: 90.6642
# epoch 29, loss: 100.8881 val_loss: 127.0661
# epoch 30, loss: 136.4231 val_loss: 140.6789
# epoch 31, loss: 134.0468 val_loss: 107.0552
# epoch 32, loss: 100.8751 val_loss: 89.3607
# epoch 33, loss: 92.6178 val_loss: 104.7969
# epoch 34, loss: 104.5295 val_loss: 109.9876
# epoch 35, loss: 108.4972 val_loss: 96.5897
# epoch 36, loss: 94.4249 val_loss: 88.2053
# epoch 37, loss: 89.7825 val_loss: 94.4145
# epoch 38, loss: 96.8870 val_loss: 97.3803
# epoch 39, loss: 95.6098 val_loss: 90.4916
# epoch 40, loss: 90.4207 val_loss: 87.2454
# epoch 41, loss: 88.4946 val_loss: 89.9965
# epoch 42, loss: 90.8976 val_loss: 90.6924
# epoch 43, loss: 93.2523 val_loss: 87.6395
# epoch 44, loss: 88.1160 val_loss: 86.7382
# epoch 45, loss: 87.2245 val_loss: 88.7520
# epoch 46, loss: 89.9517 val_loss: 87.4574
# epoch 47, loss: 87.3574 val_loss: 85.6050
# epoch 48, loss: 86.3036 val_loss: 85.8332
# epoch 49, loss: 88.1489 val_loss: 86.6148
# epoch 50, loss: 88.2208 val_loss: 85.3983
# epoch 51, loss: 86.3003 val_loss: 84.7117
# epoch 52, loss: 84.8105 val_loss: 85.2989
# epoch 53, loss: 85.1413 val_loss: 84.9043
# epoch 54, loss: 84.9012 val_loss: 83.9009
# epoch 55, loss: 85.4173 val_loss: 83.9024
# epoch 56, loss: 85.7679 val_loss: 84.0788
# epoch 57, loss: 84.2528 val_loss: 83.2503
# epoch 58, loss: 83.5850 val_loss: 82.9497
# epoch 59, loss: 82.6445 val_loss: 82.9654
# epoch 60, loss: 83.0730 val_loss: 82.7648
# epoch 61, loss: 84.3202 val_loss: 82.1315
# epoch 62, loss: 81.3923 val_loss: 81.9867
# epoch 63, loss: 81.9495 val_loss: 82.1091
# epoch 64, loss: 82.5078 val_loss: 81.5018
# epoch 65, loss: 81.9662 val_loss: 81.1221
# epoch 66, loss: 82.0848 val_loss: 80.9312
# epoch 67, loss: 81.7528 val_loss: 80.6841
# epoch 68, loss: 81.2598 val_loss: 80.3501
# epoch 69, loss: 80.1905 val_loss: 80.1004
# epoch 70, loss: 80.4055 val_loss: 79.9221
# epoch 71, loss: 80.5968 val_loss: 79.6960
# epoch 72, loss: 79.3942 val_loss: 79.3131
# epoch 73, loss: 80.4291 val_loss: 79.1387
# epoch 74, loss: 80.2660 val_loss: 78.8529
# epoch 75, loss: 80.9894 val_loss: 78.5459
# epoch 76, loss: 79.0933 val_loss: 78.2721
# epoch 77, loss: 78.2507 val_loss: 78.0529
# epoch 78, loss: 79.2524 val_loss: 77.8166
# epoch 79, loss: 79.4090 val_loss: 77.4734
# epoch 80, loss: 78.7059 val_loss: 77.2143
# epoch 81, loss: 78.5413 val_loss: 76.9446
# epoch 82, loss: 77.8553 val_loss: 76.6722
# epoch 83, loss: 78.2120 val_loss: 76.4067
# epoch 84, loss: 76.8284 val_loss: 76.1469
# epoch 85, loss: 75.9999 val_loss: 75.9108
# epoch 86, loss: 77.7030 val_loss: 75.6080
# epoch 87, loss: 76.6964 val_loss: 75.3310
# epoch 88, loss: 75.6959 val_loss: 75.0647
# epoch 89, loss: 75.1481 val_loss: 74.8205
# epoch 90, loss: 75.5108 val_loss: 74.5135
# epoch 91, loss: 75.1186 val_loss: 74.2325
# epoch 92, loss: 75.7524 val_loss: 73.9850
# epoch 93, loss: 75.2907 val_loss: 73.7245
# epoch 94, loss: 74.4632 val_loss: 73.4082
# epoch 95, loss: 74.0226 val_loss: 73.2120
# epoch 96, loss: 73.9965 val_loss: 72.8609
# epoch 97, loss: 73.7581 val_loss: 72.6068
# epoch 98, loss: 72.5122 val_loss: 72.3188
# epoch 99, loss: 72.2377 val_loss: 72.0133
# epoch 100, loss: 72.5365 val_loss: 71.7550
# epoch 101, loss: 71.6183 val_loss: 71.4695
# epoch 102, loss: 72.1999 val_loss: 71.2155
# epoch 103, loss: 72.2051 val_loss: 70.8885
# epoch 104, loss: 70.8213 val_loss: 70.6804
# epoch 105, loss: 72.0719 val_loss: 70.4040
# epoch 106, loss: 71.3273 val_loss: 70.0682
# epoch 107, loss: 69.4148 val_loss: 69.8610
# epoch 108, loss: 70.5102 val_loss: 69.6049
# epoch 109, loss: 70.2240 val_loss: 69.2032
# epoch 110, loss: 69.2395 val_loss: 69.0162
# epoch 111, loss: 69.1691 val_loss: 68.8150
# epoch 112, loss: 70.9337 val_loss: 68.5005
# epoch 113, loss: 68.6549 val_loss: 68.1638
# epoch 114, loss: 67.9940 val_loss: 68.1957
# epoch 115, loss: 67.8208 val_loss: 67.6052
# epoch 116, loss: 67.4163 val_loss: 67.3483
# epoch 117, loss: 67.2090 val_loss: 67.3995
# epoch 118, loss: 68.5116 val_loss: 66.8792
# epoch 119, loss: 66.9926 val_loss: 66.7189
# epoch 120, loss: 66.9684 val_loss: 66.3682
# epoch 121, loss: 67.8176 val_loss: 65.8333
# epoch 122, loss: 65.4696 val_loss: 65.5749
# epoch 123, loss: 66.4292 val_loss: 65.5681
# epoch 124, loss: 65.0930 val_loss: 64.9704
# epoch 125, loss: 65.8873 val_loss: 64.8297
# epoch 126, loss: 66.2965 val_loss: 64.5460
# epoch 127, loss: 65.0665 val_loss: 64.1129
# epoch 128, loss: 65.8424 val_loss: 63.9155
# epoch 129, loss: 65.2453 val_loss: 63.7109
# epoch 130, loss: 64.5198 val_loss: 63.2502
# epoch 131, loss: 64.2448 val_loss: 62.9808
# epoch 132, loss: 63.3755 val_loss: 62.6565
# epoch 133, loss: 63.8360 val_loss: 62.4270
# epoch 134, loss: 63.4754 val_loss: 62.1158
# epoch 135, loss: 63.0881 val_loss: 61.7820
# epoch 136, loss: 62.6440 val_loss: 61.4911
# epoch 137, loss: 61.7673 val_loss: 61.2932
# epoch 138, loss: 61.7280 val_loss: 60.9060
# epoch 139, loss: 61.5878 val_loss: 60.7818
# epoch 140, loss: 60.7277 val_loss: 60.5079
# epoch 141, loss: 62.1060 val_loss: 60.0378
# epoch 142, loss: 60.1295 val_loss: 59.9001
# epoch 143, loss: 60.1227 val_loss: 59.4946
# epoch 144, loss: 60.4202 val_loss: 59.2189
# epoch 145, loss: 60.1703 val_loss: 58.8934
# epoch 146, loss: 60.2249 val_loss: 58.6373
# epoch 147, loss: 59.0714 val_loss: 58.3343
# epoch 148, loss: 58.5643 val_loss: 58.1048
# epoch 149, loss: 58.7045 val_loss: 57.8603
# epoch 150, loss: 58.5930 val_loss: 57.5058
# epoch 151, loss: 57.9969 val_loss: 57.3454
# epoch 152, loss: 58.3691 val_loss: 56.9090
# epoch 153, loss: 58.2569 val_loss: 56.6257
# epoch 154, loss: 57.3625 val_loss: 56.3497
# epoch 155, loss: 56.9236 val_loss: 56.1929
# epoch 156, loss: 57.1272 val_loss: 55.7751
# epoch 157, loss: 55.0212 val_loss: 55.5471
# epoch 158, loss: 57.0488 val_loss: 55.2902
# epoch 159, loss: 56.1587 val_loss: 54.9770
# epoch 160, loss: 55.0537 val_loss: 54.8556
# epoch 161, loss: 54.7727 val_loss: 54.4592
# epoch 162, loss: 54.9523 val_loss: 54.2575
# epoch 163, loss: 55.0090 val_loss: 53.9527
# epoch 164, loss: 54.8347 val_loss: 53.5665
# epoch 165, loss: 54.2078 val_loss: 53.5138
# epoch 166, loss: 53.7735 val_loss: 53.0278
# epoch 167, loss: 53.0011 val_loss: 52.9856
# epoch 168, loss: 53.6489 val_loss: 52.7531
# epoch 169, loss: 52.5644 val_loss: 52.2160
# epoch 170, loss: 53.6439 val_loss: 52.1116
# epoch 171, loss: 53.1111 val_loss: 51.7163
# epoch 172, loss: 53.4326 val_loss: 51.4888
# epoch 173, loss: 52.6478 val_loss: 51.2642
# epoch 174, loss: 51.4427 val_loss: 50.9170
# epoch 175, loss: 51.2149 val_loss: 50.6840
# epoch 176, loss: 51.9649 val_loss: 50.3753
# epoch 177, loss: 50.4479 val_loss: 50.1444
# epoch 178, loss: 51.3809 val_loss: 49.9282
# epoch 179, loss: 49.4599 val_loss: 49.6278
# epoch 180, loss: 49.4692 val_loss: 49.4155
# epoch 181, loss: 50.5910 val_loss: 49.1307
# epoch 182, loss: 49.7753 val_loss: 49.0096
# epoch 183, loss: 49.6315 val_loss: 48.5986
# epoch 184, loss: 49.1085 val_loss: 48.4117
# epoch 185, loss: 48.5084 val_loss: 48.1381
# epoch 186, loss: 48.6402 val_loss: 47.8907
# epoch 187, loss: 47.2934 val_loss: 47.6644
# epoch 188, loss: 47.8461 val_loss: 47.4592
# epoch 189, loss: 48.2005 val_loss: 47.1488
# epoch 190, loss: 48.1908 val_loss: 46.9471
# epoch 191, loss: 48.2139 val_loss: 46.7345
# epoch 192, loss: 47.1607 val_loss: 46.5414
# epoch 193, loss: 45.7980 val_loss: 46.3553
# epoch 194, loss: 47.0961 val_loss: 46.2845
# epoch 195, loss: 45.3224 val_loss: 45.7673
# epoch 196, loss: 46.0138 val_loss: 45.6777
# epoch 197, loss: 46.2031 val_loss: 45.6742
# epoch 198, loss: 45.7966 val_loss: 45.2647
# epoch 199, loss: 45.1363 val_loss: 45.0680
# epoch 200, loss: 45.6381 val_loss: 44.7449
# epoch 201, loss: 44.6855 val_loss: 44.4789
# epoch 202, loss: 43.0192 val_loss: 44.4229
# epoch 203, loss: 44.3749 val_loss: 44.3132
# epoch 204, loss: 44.2900 val_loss: 43.8597
# epoch 205, loss: 43.9826 val_loss: 43.6811
# epoch 206, loss: 44.0326 val_loss: 43.4651
# epoch 207, loss: 43.6037 val_loss: 43.3398
# epoch 208, loss: 43.1628 val_loss: 43.2776
# epoch 209, loss: 43.8451 val_loss: 42.8792
# epoch 210, loss: 44.0014 val_loss: 42.8336
# epoch 211, loss: 42.7534 val_loss: 42.4563
# epoch 212, loss: 41.6279 val_loss: 42.3888
# epoch 213, loss: 42.5507 val_loss: 42.0843
# epoch 214, loss: 43.3487 val_loss: 41.9236
# epoch 215, loss: 42.5983 val_loss: 41.9148
# epoch 216, loss: 42.1683 val_loss: 41.5627
# epoch 217, loss: 41.8341 val_loss: 41.5692
# epoch 218, loss: 43.1118 val_loss: 41.7748
# epoch 219, loss: 41.8033 val_loss: 41.0578
# epoch 220, loss: 41.5451 val_loss: 41.0721
# epoch 221, loss: 41.4065 val_loss: 40.7213
# epoch 222, loss: 40.2930 val_loss: 40.6672
# epoch 223, loss: 42.2287 val_loss: 40.3821
# epoch 224, loss: 40.8094 val_loss: 40.3431
# epoch 225, loss: 40.3024 val_loss: 40.0788
# epoch 226, loss: 40.0235 val_loss: 40.1755
# epoch 227, loss: 40.4494 val_loss: 40.1053
# epoch 228, loss: 40.4127 val_loss: 39.6509
# epoch 229, loss: 38.5056 val_loss: 39.6204
# epoch 230, loss: 41.3674 val_loss: 39.4614
# epoch 231, loss: 39.2927 val_loss: 39.2207
# epoch 232, loss: 39.2291 val_loss: 39.0743
# epoch 233, loss: 38.6528 val_loss: 38.9654
# epoch 234, loss: 39.7237 val_loss: 38.8666
# epoch 235, loss: 38.7841 val_loss: 38.6908
# epoch 236, loss: 39.3054 val_loss: 38.5716
# epoch 237, loss: 39.6257 val_loss: 38.4688
# epoch 238, loss: 37.9126 val_loss: 38.3437
# epoch 239, loss: 39.4789 val_loss: 38.2988
# epoch 240, loss: 38.3995 val_loss: 38.1000
# epoch 241, loss: 38.5840 val_loss: 38.1631
# epoch 242, loss: 37.8242 val_loss: 37.8972
# epoch 243, loss: 39.5615 val_loss: 37.8903
# epoch 244, loss: 37.5606 val_loss: 37.6992
# epoch 245, loss: 38.1236 val_loss: 37.7433
# epoch 246, loss: 37.9785 val_loss: 37.5326
# epoch 247, loss: 36.6800 val_loss: 37.4436
# epoch 248, loss: 38.5505 val_loss: 37.3420
# epoch 249, loss: 37.2428 val_loss: 37.2639
# epoch 250, loss: 37.4602 val_loss: 37.0764
# epoch 251, loss: 38.5286 val_loss: 37.0500
# epoch 252, loss: 38.4274 val_loss: 36.9723
# epoch 253, loss: 38.4655 val_loss: 36.9559
# epoch 254, loss: 36.7732 val_loss: 36.8211
# epoch 255, loss: 37.4522 val_loss: 36.7293
# epoch 256, loss: 36.7770 val_loss: 36.6474
# epoch 257, loss: 36.7991 val_loss: 36.5309
# epoch 258, loss: 37.9244 val_loss: 36.7053
# epoch 259, loss: 36.3339 val_loss: 36.3737
# epoch 260, loss: 36.7426 val_loss: 36.3688
# epoch 261, loss: 36.8374 val_loss: 36.2193
# epoch 262, loss: 37.8975 val_loss: 36.1564
# epoch 263, loss: 37.0407 val_loss: 36.0879
# epoch 264, loss: 37.5647 val_loss: 36.1102
# epoch 265, loss: 37.7482 val_loss: 35.9694
# epoch 266, loss: 37.2160 val_loss: 35.9277
# epoch 267, loss: 36.9641 val_loss: 35.8487
# epoch 268, loss: 36.0380 val_loss: 35.7908
# epoch 269, loss: 36.9276 val_loss: 35.7275
# epoch 270, loss: 36.4449 val_loss: 35.7165
# epoch 271, loss: 36.0831 val_loss: 35.6335
# epoch 272, loss: 36.6927 val_loss: 35.6044
# epoch 273, loss: 36.8385 val_loss: 35.6125
# epoch 274, loss: 36.0471 val_loss: 35.7310
# epoch 275, loss: 35.8559 val_loss: 35.6276
# epoch 276, loss: 36.0023 val_loss: 35.5624
# epoch 277, loss: 35.9756 val_loss: 35.6125
# epoch 278, loss: 35.9445 val_loss: 35.3045
# epoch 279, loss: 36.2691 val_loss: 35.6368
# epoch 280, loss: 36.2374 val_loss: 35.2985
# epoch 281, loss: 35.4705 val_loss: 35.2450
# epoch 282, loss: 35.4162 val_loss: 35.3262
# epoch 283, loss: 36.6155 val_loss: 35.1367
# epoch 284, loss: 35.8595 val_loss: 35.2365
# epoch 285, loss: 35.9323 val_loss: 35.0432
# epoch 286, loss: 34.9654 val_loss: 35.2356
# epoch 287, loss: 35.8239 val_loss: 35.0436
# epoch 288, loss: 35.0138 val_loss: 35.3002
# epoch 289, loss: 34.7354 val_loss: 34.9925
# epoch 290, loss: 34.2855 val_loss: 34.9324
# epoch 291, loss: 34.9934 val_loss: 35.1177
# epoch 292, loss: 36.0729 val_loss: 34.9696
# epoch 293, loss: 34.7298 val_loss: 35.0177
# epoch 294, loss: 35.7909 val_loss: 34.8312
# epoch 295, loss: 35.6130 val_loss: 35.1784
# epoch 296, loss: 35.6871 val_loss: 34.8882
# epoch 297, loss: 35.0369 val_loss: 34.9123
# epoch 298, loss: 35.3124 val_loss: 35.0116
# epoch 299, loss: 35.7953 val_loss: 34.7047
# epoch 300, loss: 35.8444 val_loss: 35.0302
# epoch 301, loss: 34.4652 val_loss: 34.7616
# epoch 302, loss: 36.6034 val_loss: 34.9880
# epoch 303, loss: 35.8123 val_loss: 35.1351
# epoch 304, loss: 35.1194 val_loss: 34.6739
# epoch 305, loss: 34.1150 val_loss: 35.2386
# epoch 306, loss: 36.3251 val_loss: 34.6169
# epoch 307, loss: 34.9994 val_loss: 35.1187
# epoch 308, loss: 35.7804 val_loss: 34.5961
# epoch 309, loss: 34.4182 val_loss: 34.7680
# epoch 310, loss: 35.0242 val_loss: 34.5084
# epoch 311, loss: 35.6275 val_loss: 34.8691
# epoch 312, loss: 34.9232 val_loss: 34.7063
# epoch 313, loss: 35.7570 val_loss: 34.6936
# epoch 314, loss: 34.9356 val_loss: 34.8318
# epoch 315, loss: 34.6017 val_loss: 34.4749
# epoch 316, loss: 36.1848 val_loss: 34.5150
# epoch 317, loss: 35.3916 val_loss: 34.9305
# epoch 318, loss: 34.4213 val_loss: 34.4869
# epoch 319, loss: 34.9857 val_loss: 34.6211
# epoch 320, loss: 36.1352 val_loss: 34.5336
# epoch 321, loss: 35.8156 val_loss: 34.7337
# epoch 322, loss: 35.7430 val_loss: 34.8958
# epoch 323, loss: 36.4901 val_loss: 34.4367
# epoch 324, loss: 35.2823 val_loss: 35.4595
# epoch 325, loss: 36.0691 val_loss: 34.4445
# epoch 326, loss: 34.9166 val_loss: 34.5884
# epoch 327, loss: 34.0526 val_loss: 34.4898
# epoch 328, loss: 36.1142 val_loss: 34.3700
# epoch 329, loss: 34.8097 val_loss: 34.3911
# epoch 330, loss: 35.7071 val_loss: 34.4373
# epoch 331, loss: 33.6418 val_loss: 34.4196
# epoch 332, loss: 36.2324 val_loss: 34.3206
# epoch 333, loss: 34.7305 val_loss: 34.6292
# epoch 334, loss: 33.7419 val_loss: 34.4380
# epoch 335, loss: 34.6467 val_loss: 34.4474
# epoch 336, loss: 35.8791 val_loss: 34.5071
# epoch 337, loss: 34.4899 val_loss: 34.3294
# epoch 338, loss: 34.5653 val_loss: 34.5995
# epoch 339, loss: 34.8499 val_loss: 34.3368
# epoch 340, loss: 33.8698 val_loss: 34.4068
# epoch 341, loss: 34.3943 val_loss: 34.4066
# epoch 342, loss: 35.1282 val_loss: 34.3131
# epoch 343, loss: 35.1962 val_loss: 34.3592
# epoch 344, loss: 35.8004 val_loss: 34.3896
# epoch 345, loss: 34.4301 val_loss: 34.3112
# epoch 346, loss: 34.8890 val_loss: 34.2784
# epoch 347, loss: 34.5059 val_loss: 34.2795
# epoch 348, loss: 34.2673 val_loss: 34.3854
# epoch 349, loss: 33.9917 val_loss: 34.2805
# epoch 350, loss: 35.6977 val_loss: 34.4062
# epoch 351, loss: 34.6895 val_loss: 34.3001
# epoch 352, loss: 34.9348 val_loss: 34.3203
# epoch 353, loss: 35.6989 val_loss: 34.2492
# epoch 354, loss: 35.3767 val_loss: 34.3813
# epoch 355, loss: 35.2644 val_loss: 34.8640
# epoch 356, loss: 35.6797 val_loss: 34.3362
# epoch 357, loss: 34.2231 val_loss: 34.3203
# epoch 358, loss: 34.9571 val_loss: 34.5586
# epoch 359, loss: 34.5564 val_loss: 34.3632
# epoch 360, loss: 37.0655 val_loss: 34.2633
# epoch 361, loss: 33.7208 val_loss: 34.7459
# epoch 362, loss: 36.1904 val_loss: 34.2478
# epoch 363, loss: 34.1878 val_loss: 34.4468
# epoch 364, loss: 35.0061 val_loss: 34.3297
# epoch 365, loss: 34.8716 val_loss: 34.2458
# epoch 366, loss: 35.1328 val_loss: 34.2667
# epoch 367, loss: 34.5309 val_loss: 34.5085
# epoch 368, loss: 34.7825 val_loss: 34.2797
# epoch 369, loss: 35.8995 val_loss: 34.8118
# epoch 370, loss: 35.1945 val_loss: 34.3895
# epoch 371, loss: 34.2691 val_loss: 34.2540
# epoch 372, loss: 34.1239 val_loss: 34.3328
# epoch 373, loss: 34.7320 val_loss: 34.2170
# epoch 374, loss: 33.9663 val_loss: 34.2726
# epoch 375, loss: 33.3537 val_loss: 34.2580
# epoch 376, loss: 34.9437 val_loss: 34.2288
# epoch 377, loss: 34.8995 val_loss: 34.2679
# epoch 378, loss: 35.0509 val_loss: 34.2286
# epoch 379, loss: 33.8884 val_loss: 34.3505
# epoch 380, loss: 34.8958 val_loss: 34.3728
# epoch 381, loss: 35.4701 val_loss: 34.2999
# epoch 382, loss: 34.1843 val_loss: 34.3381
# epoch 383, loss: 34.7821 val_loss: 34.3360
# epoch 384, loss: 35.3434 val_loss: 34.2223
# epoch 385, loss: 34.6719 val_loss: 34.3570
# epoch 386, loss: 34.9700 val_loss: 34.3601
# epoch 387, loss: 33.3673 val_loss: 34.3093
# epoch 388, loss: 33.7284 val_loss: 34.4610
# epoch 389, loss: 34.0117 val_loss: 34.4133
# epoch 390, loss: 34.2298 val_loss: 34.2015
# epoch 391, loss: 34.4421 val_loss: 34.2719
# epoch 392, loss: 33.8887 val_loss: 34.3201
# epoch 393, loss: 33.7280 val_loss: 34.2379
# epoch 394, loss: 35.5390 val_loss: 34.3154
# epoch 395, loss: 35.2856 val_loss: 34.2795
# epoch 396, loss: 34.8306 val_loss: 34.4286
# epoch 397, loss: 35.0804 val_loss: 34.2012
# epoch 398, loss: 35.0733 val_loss: 34.2415
# epoch 399, loss: 34.1838 val_loss: 34.5622
# epoch 400, loss: 34.3122 val_loss: 34.2269
# epoch 401, loss: 33.6290 val_loss: 34.5378
# epoch 402, loss: 34.1542 val_loss: 34.8174
# epoch 403, loss: 35.4646 val_loss: 34.2138
# epoch 404, loss: 35.6356 val_loss: 34.7620
# epoch 405, loss: 35.1595 val_loss: 34.8823
# epoch 406, loss: 35.2164 val_loss: 34.2878
# epoch 407, loss: 35.2562 val_loss: 34.7486
# epoch 408, loss: 35.5201 val_loss: 34.3277
# epoch 409, loss: 35.0619 val_loss: 34.8703
# epoch 410, loss: 34.7140 val_loss: 34.4539
# epoch 411, loss: 34.4558 val_loss: 34.2944
# epoch 412, loss: 34.3169 val_loss: 34.2909
# epoch 413, loss: 34.6805 val_loss: 34.2057
# epoch 414, loss: 34.2245 val_loss: 34.5094
# epoch 415, loss: 34.1295 val_loss: 34.2684
# epoch 416, loss: 34.1373 val_loss: 34.4433
# epoch 417, loss: 35.4727 val_loss: 34.3345
# epoch 418, loss: 35.2454 val_loss: 34.3130
# epoch 419, loss: 35.6323 val_loss: 34.3002
# epoch 420, loss: 35.0851 val_loss: 35.1393
# epoch 421, loss: 35.2548 val_loss: 34.7408
# epoch 422, loss: 34.9329 val_loss: 34.7789
# epoch 423, loss: 36.1426 val_loss: 35.3695
# epoch 424, loss: 37.5329 val_loss: 34.2480
# epoch 425, loss: 37.1932 val_loss: 36.4765
# epoch 426, loss: 34.1587 val_loss: 37.5949
# epoch 427, loss: 36.3453 val_loss: 34.2319
# epoch 428, loss: 35.1232 val_loss: 35.4799
# epoch 429, loss: 36.1908 val_loss: 34.9933
# epoch 430, loss: 34.5532 val_loss: 34.2483
# epoch 431, loss: 35.5266 val_loss: 34.4858
# epoch 432, loss: 34.8337 val_loss: 34.6726
# epoch 433, loss: 35.6340 val_loss: 34.2041
# epoch 434, loss: 34.6825 val_loss: 34.5401
# epoch 435, loss: 34.6598 val_loss: 34.1924
# epoch 436, loss: 34.4771 val_loss: 34.2939
# epoch 437, loss: 34.1239 val_loss: 34.2936
# epoch 438, loss: 33.9279 val_loss: 34.6145
# epoch 439, loss: 34.8171 val_loss: 34.2931
# epoch 440, loss: 34.7659 val_loss: 34.2194
# epoch 441, loss: 35.9784 val_loss: 34.2092
# epoch 442, loss: 34.2923 val_loss: 34.2867
# epoch 443, loss: 35.3055 val_loss: 34.2170
# epoch 444, loss: 34.3489 val_loss: 34.2279
# epoch 445, loss: 35.3175 val_loss: 34.2499
# epoch 446, loss: 34.1561 val_loss: 34.2039
# epoch 447, loss: 34.5952 val_loss: 34.2708
# epoch 448, loss: 34.1721 val_loss: 34.2074
# epoch 449, loss: 34.4546 val_loss: 34.3101
# epoch 450, loss: 33.9324 val_loss: 34.6075
# epoch 451, loss: 36.3955 val_loss: 34.3784
# epoch 452, loss: 36.3590 val_loss: 34.4779
# epoch 453, loss: 33.8308 val_loss: 36.0069
# epoch 454, loss: 35.0943 val_loss: 34.6842
# epoch 455, loss: 35.0600 val_loss: 34.2907
# epoch 456, loss: 35.6204 val_loss: 34.3951
# epoch 457, loss: 33.4967 val_loss: 34.9381
# epoch 458, loss: 35.5948 val_loss: 34.2355
# epoch 459, loss: 35.9769 val_loss: 34.2027
# epoch 460, loss: 34.3404 val_loss: 35.4687
# epoch 461, loss: 35.7066 val_loss: 34.5617
# epoch 462, loss: 35.1429 val_loss: 34.4694
# epoch 463, loss: 35.7631 val_loss: 34.9228
# epoch 464, loss: 36.3438 val_loss: 34.2633
# epoch 465, loss: 36.5288 val_loss: 34.4342
# epoch 466, loss: 34.9689 val_loss: 34.9025
# epoch 467, loss: 35.8392 val_loss: 34.3134
# epoch 468, loss: 34.7857 val_loss: 34.2282
# epoch 469, loss: 33.6665 val_loss: 34.2360
# epoch 470, loss: 34.8560 val_loss: 34.2978
# epoch 471, loss: 35.3388 val_loss: 34.2016
# epoch 472, loss: 34.0788 val_loss: 34.7783
# epoch 473, loss: 34.5831 val_loss: 34.4972
# epoch 474, loss: 35.0202 val_loss: 34.2693
# epoch 475, loss: 34.8074 val_loss: 34.2278
# epoch 476, loss: 34.7496 val_loss: 34.5661
# epoch 477, loss: 33.9690 val_loss: 34.5330
# epoch 478, loss: 34.4014 val_loss: 34.4365
# epoch 479, loss: 33.7763 val_loss: 34.7348
# epoch 480, loss: 34.5215 val_loss: 34.4441
# epoch 481, loss: 36.0193 val_loss: 34.2984
# epoch 482, loss: 34.6585 val_loss: 35.4373
# epoch 483, loss: 35.9362 val_loss: 34.6237
# epoch 484, loss: 35.9244 val_loss: 34.4867
# epoch 485, loss: 35.7690 val_loss: 35.8860
# epoch 486, loss: 36.6318 val_loss: 34.8221
# epoch 487, loss: 37.2790 val_loss: 34.2322
# epoch 488, loss: 34.4561 val_loss: 35.7024
# epoch 489, loss: 35.1522 val_loss: 35.3024
# epoch 490, loss: 35.5540 val_loss: 34.2194
# epoch 491, loss: 34.7802 val_loss: 34.5893
# epoch 492, loss: 35.0158 val_loss: 34.3287
# epoch 493, loss: 36.4908 val_loss: 34.7682
# epoch 494, loss: 34.8318 val_loss: 36.1764
# epoch 495, loss: 35.8050 val_loss: 34.4993
# epoch 496, loss: 35.5561 val_loss: 34.6796
# epoch 497, loss: 34.8656 val_loss: 36.0983
# epoch 498, loss: 34.8562 val_loss: 34.3252
# epoch 499, loss: 35.0717 val_loss: 34.7331
# best_epoch 435

# %%
test_net = NET().to(device)
test_net.eval()
test_net.load_state_dict(torch.load('model' + str(best_epoch) +'.pth'))
# Out:
# <All keys matched successfully>

# %%
train_loss_list = torch.tensor(train_loss_list)
val_loss_list = torch.tensor(val_loss_list)

plt.xlim(0, 1000)
plt.plot(range(len(train_loss_list)), train_loss_list, label="Train")
plt.plot(range(len(val_loss_list)), val_loss_list, label="Test")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Error")
plt.show()

# %%
import seaborn
def test():
    test_net.eval()
    running_loss = 0
    with torch.no_grad():
        total_max_temp_error = 0
        total_min_temp_error = 0
        max_error_x = 0
        max_error_y = 0
        min_error_x = 0
        min_error_y = 0
        error_per_pix = 0
        loss_sum = 0
        max_error_x_abs = 0
        max_error_y_abs = 0
        min_error_x_abs = 0
        min_error_y_abs = 0
            
        estimate_list = []

        for batch_idx, (x, c) in enumerate(test_loader):
            estimate_start = time.time()
            print('=================================')
            x, c = tmp.next()
            x = x.to(device)
            c = c.to(device)
            y = model(x)
            estimate_end = time.time()
            estimate_duration = -estimate_start+estimate_end
            print("{}個目のモデルの推定時間は：{}秒です".format(batch_idx+1, estimate_duration))
            estimate_list.append(estimate_duration)
            continue
            loss = criterion(y, c)
            loss_unit = torch.sum(torch.abs(y-c))/16/18
            loss_sum = loss_sum + loss_unit
            running_loss += loss.item()
            
            
            y = y.cpu()
            c = c.cpu()
            c_reshaped = c.reshape(16, 18)
            seaborn.heatmap(c_reshaped, vmin=18, vmax=25)
            plt.show()
            y_reshaped = y.reshape(16, 18)
            seaborn.heatmap(y_reshaped, vmin=18, vmax=25)
            plt.show()
            
            #最高温度のずれ
            max_temp_output = torch.max(c)
            max_temp_target = torch.max(y)
            max_temp_error = max_temp_output - max_temp_target
            total_max_temp_error = total_max_temp_error + max_temp_error

            #最低温度のずれ
            min_temp_output = torch.min(c)
            min_temp_target = torch.min(y)
            min_temp_error = min_temp_output - min_temp_target
            total_min_temp_error = total_min_temp_error + min_temp_error

            #最高温度を示すピクセルの座標のずれ(絶対値)
            max_temp_arg = torch.argmax(c)
            max_x_output = (max_temp_arg + 1)%18 -1
            max_y_output = -(max_temp_arg + 1)//18

            max_temp_arg = torch.argmax(y)
            max_x_target = (max_temp_arg + 1)%18 -1
            max_y_target = -(max_temp_arg + 1)//18
            
            max_error_x = max_error_x + abs(max_x_output - max_x_target)
            max_error_y = max_error_y + abs(max_y_output - max_y_target)

            # 最低温度を示すピクセルの座標のずれ(絶対値)
            min_temp_arg = torch.argmin(c)
            min_x_output = (min_temp_arg + 1)%18 -1
            min_y_output = -(min_temp_arg + 1)//18

            min_temp_arg = torch.argmin(y)
            min_x_target = (min_temp_arg + 1)%18 -1
            min_y_target = -(min_temp_arg + 1)//18
            
            min_error_x = min_error_x + abs(min_x_output - min_x_target)
            min_error_y = min_error_y + abs(min_y_output - min_y_target)

    print("平均時間は{}秒です".format(sum(estimate_list)/len(estimate_list)))
    return 0

    print('1ピクセルあたりの誤差', loss_sum/len(test_loader))
    print('最高温度のずれ', total_max_temp_error/len(test_loader))      
    print('最低温度のずれ', total_min_temp_error/len(test_loader))
    print('最高温度を示すピクセルの座標のずれ', max_error_x_abs/len(test_loader), max_error_y_abs/len(test_loader), )
    print('最低温度を示すピクセルの座標のずれ', min_error_x_abs/len(test_loader), min_error_y_abs/len(test_loader), )
    
    print("batch_size: {}　です。頑張ってください".format(batchsize))
    print(fpath)
    p = [loss_sum/len(test_loader), total_max_temp_error/len(test_loader), total_min_temp_error/len(test_loader), max_error_x/len(test_loader), max_error_y/len(test_loader), min_error_x/len(test_loader), min_error_y/len(test_loader), max_error_x_abs/len(test_loader), max_error_y_abs/len(test_loader), min_error_x_abs/len(test_loader), min_error_y_abs/len(test_loader), best_epoch]
    p = [float(x) for x in p]
    p.insert(0, "条件"+str(histwindow))
    print(*p, sep=', ')

    val_loss = running_loss / len(test_loader)

# %%
test()
# Out:
# =================================
# /tmp/ipykernel_602358/3802107902.py:63: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_x_output = (max_temp_arg + 1)//18
# /tmp/ipykernel_602358/3802107902.py:67: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_x_target = (max_temp_arg + 1)//18
# /tmp/ipykernel_602358/3802107902.py:78: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   min_x_output = (min_temp_arg + 1)//18
# /tmp/ipykernel_602358/3802107902.py:82: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   min_x_target = (min_temp_arg + 1)//18
# /tmp/ipykernel_602358/3802107902.py:90: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_x_output_abs = (max_temp_arg_abs + 1)//18
# /tmp/ipykernel_602358/3802107902.py:94: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_x_target_abs = (max_temp_arg_abs + 1)//18
# /tmp/ipykernel_602358/3802107902.py:101: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   min_x_output_abs = (min_temp_arg_abs + 1)//18
# /tmp/ipykernel_602358/3802107902.py:105: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   min_x_target_abs = (min_temp_arg_abs + 1)//18
# =================================
# =================================
# =================================
# =================================
# =================================
# =================================
# =================================
# =================================
# =================================
# 1ピクセルあたりの誤差その１ tensor(2.4024, device='cuda:0')
# 1ピクセルあたりの誤差 tensor(3.1094, device='cuda:0')
# 最高温度のずれ tensor(6.5295)
# 最低温度のずれ tensor(-3.1184)
# 最高温度を示すピクセルの座標のずれ tensor(5.1000) tensor(6.5000)
# 最低温度を示すピクセルの座標のずれ tensor(5.1000) tensor(1.6000)
# abs最高温度を示すピクセルの座標のずれ tensor(7.1000) tensor(8.7000)
# abs最低温度を示すピクセルの座標のずれ tensor(5.7000) tensor(2.)
# batch_size: 100　です。頑張ってください
# /proj/NARO/sonoda/noken/noken_0_50_selected
# 条件1, 2.4024224281311035, 6.529533386230469, -3.118433952331543, 5.099999904632568, 6.5, 5.099999904632568, 1.600000023841858, 7.099999904632568, 8.699999809265137, 5.699999809265137, 2.0, 435.0
